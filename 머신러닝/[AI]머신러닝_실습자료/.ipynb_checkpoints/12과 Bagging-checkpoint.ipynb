# %% [markdown]
# # Ensemble : Bagging

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) import

# %%
#라이브러리들을 불러오자.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 전처리
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# 모델링
from sklearn.tree import plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import * 
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

import warnings    # 경고메시지 제외
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### (2) 데이터 준비

# %% [markdown]
# * 변수설명
#     * COLLEGE : 대학 졸업여부
#     * INCOME : 연수입
#     * OVERAGE : 월평균 초과사용 시간(분)
#     * LEFTOVER : 월평균 잔여시간비율(%)
#     * HOUSE : 집값
#     * HANDSET_PRICE : 스마트폰 가격
#     * OVER_15MINS_CALLS_PER_MONTH : 월평균 장기통화(15분이상) 횟수
#     * AVERAGE_CALL_DURATION : 평균 통화 시간
#     * REPORTED_SATISFACTION : 만족도 설문조사 결과
#     * REPORTED_USAGE_LEVEL : 사용도 자가진단 결과
#     * CONSIDERING_CHANGE_OF_PLAN : 향후 변경계획 설문조사 결과
#     * CHURN : 이탈(번호이동) 여부 (1-이탈, 0-잔류, Target 변수)

# %%
# 데이터를 불러옵시다.
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/mobile_cust_churn.csv'
data = pd.read_csv(path)
data = data.sample(5000, random_state = 2022)
data['CHURN'] = data['CHURN'].map({'LEAVE':1, 'STAY':0})
data.head()
# Out:
#           id  COLLEGE  INCOME  OVERAGE  LEFTOVER   HOUSE  HANDSET_PRICE  \
# 3178    3179        0  119512       51        31  248566            229
# 14926  14927        1  142144      192        15  774317            581
# 15116  15117        1  142308        0        79  306426            497
# 12733  12734        1  113385        0         0  333599            819
# 14032  14033        1   90348      209        10  637286            360
#
#        OVER_15MINS_CALLS_PER_MONTH  AVERAGE_CALL_DURATION  \
# 3178                             5                      2
# 14926                           29                      4
# 15116                            1                      1
# 12733                            1                      6
# 14032                           26                      4
#
#       REPORTED_SATISFACTION REPORTED_USAGE_LEVEL CONSIDERING_CHANGE_OF_PLAN  \
# 3178               very_sat            very_high                considering
# ...

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# ### (1) 데이터 정리

# %%
drop_cols = ['id']
data.drop(drop_cols, axis = 1, inplace = True )

# %% [markdown]
# ### (2) 데이터분할1 : x, y 나누기

# %%
target = 'CHURN'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %% [markdown]
# ### (3) NA 조치

# %% [markdown]
# ### (4) 가변수화

# %%
dumm_cols = ['REPORTED_SATISFACTION','REPORTED_USAGE_LEVEL','CONSIDERING_CHANGE_OF_PLAN']
x = pd.get_dummies(x, columns = dumm_cols, drop_first = True)

# %% [markdown]
# ### (5) 데이터분할2 : train : validation

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=.3, random_state = 2022)

# %% [markdown]
# ## 3.모델링 : 랜덤포레스트

# %%
# 모델 선언
model = RandomForestClassifier(n_estimators = 5, max_depth = 3) #트리 5개 만들어라, 기본값 100

# %%
# 학습
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=5)

# %%
# 예측
pred = model.predict(x_val)

# %%
# 평가 -> 앙상블은 시각화해서 보는거에 의미가 없다.-> 볼수는 있음
print(classification_report(y_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69       769
#            1       0.68      0.63      0.66       731
#
#     accuracy                           0.68      1500
#    macro avg       0.68      0.67      0.67      1500
# weighted avg       0.68      0.68      0.67      1500

# %% [markdown]
# ## 4.시각화와 변수중요도

# %% [markdown]
# ### (1) 모델의 내부를 살펴봅시다.

# %%
# 5개 decision tree
model.estimators_
# Out:
# [DecisionTreeClassifier(max_depth=3, max_features='auto', random_state=21252149),
#  DecisionTreeClassifier(max_depth=3, max_features='auto', random_state=145027444),
#  DecisionTreeClassifier(max_depth=3, max_features='auto',
#                         random_state=1197491604),
#  DecisionTreeClassifier(max_depth=3, max_features='auto',
#                         random_state=1732181340),
#  DecisionTreeClassifier(max_depth=3, max_features='auto', random_state=115891430)]

# %%
# 각 트리별로 시각화 할 수 있다. -> 추천X 의미없음
plt.figure(figsize=(20,6))
#첫번째 트리 보여줘
plot_tree(model.estimators_[0], 
               feature_names = x_train.columns,
               class_names= ['LEAVE','STAY'], 
               filled = True, fontsize = 8);

# %% [markdown]
# ### (2) 변수 중요도

# %%
# 개별트리에 대한 변수 중요도
print(x_train.columns)
#전체의 변수 중요도
print(model.feature_importances_)
# Out:
# Index(['COLLEGE', 'INCOME', 'OVERAGE', 'LEFTOVER', 'HOUSE', 'HANDSET_PRICE',
#        'OVER_15MINS_CALLS_PER_MONTH', 'AVERAGE_CALL_DURATION',
#        'REPORTED_SATISFACTION_sat', 'REPORTED_SATISFACTION_unsat',
#        'REPORTED_SATISFACTION_very_sat', 'REPORTED_SATISFACTION_very_unsat',
#        'REPORTED_USAGE_LEVEL_high', 'REPORTED_USAGE_LEVEL_little',
#        'REPORTED_USAGE_LEVEL_very_high', 'REPORTED_USAGE_LEVEL_very_little',
#        'CONSIDERING_CHANGE_OF_PLAN_considering',
#        'CONSIDERING_CHANGE_OF_PLAN_never_thought',
#        'CONSIDERING_CHANGE_OF_PLAN_no', 'CONSIDERING_CHANGE_OF_PLAN_perhaps'],
#       dtype='object')
# [0.00000000e+00 8.73983617e-02 2.17199553e-01 1.12628402e-01
#  3.40236272e-01 6.08987667e-02 1.28130425e-01 3.14122735e-02
#  0.00000000e+00 0.00000000e+00 1.16812406e-04 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 2.49492013e-03 1.94842130e-02]

# %% [markdown]
# * 변수중요도 그래프 그리기 함수 만들기

# %%
def plot_feature_importance(importance, names):
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_df = pd.DataFrame(data)

    fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_df.reset_index(drop=True, inplace = True)

    plt.figure(figsize=(10,8))
    sns.barplot(x='feature_importance', y='feature_names', data = fi_df)

    plt.xlabel('FEATURE IMPORTANCE')
    plt.ylabel('FEATURE NAMES')
    plt.grid()

    return fi_df

# %%
result = plot_feature_importance(model.feature_importances_, x_train.columns)

# %% [markdown]
# ## 5.실습: random forest 튜닝
#
# * grid search를 수행합니다.
#     * ① n_estimators 의 갯수를 5 ~ 200까지 5개씩 증가시켜가며 튜닝해 봅시다.
#     * ② max_features를 1 ~ feature갯수까지 1씩 증가시켜가며 튜닝해 봅시다.
#     * ③ n_estimators, max_features를 동시에 튜닝.
#
# * 모델링 후 cv 평가 결과를 차트로 그려봅시다.
# * 튜닝된 모델로 부터 변수중요도를 뽑아 봅시다.

# %% [markdown]
# ### (3) n_estimators와 max_features를 한꺼번에 튜닝

# %%
x_train.shape
# Out:
# (3500, 20)

# %%
params={'n_estimators': range(5,201,5),'max_features':range(1,21)}

# %%
model2=RandomForestClassifier()

# %%
model2_gs=GridSearchCV(model2,params,cv=5,verbose=3)

# %%
model2_gs.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 800 candidates, totalling 4000 fits
# [CV 1/5] END .................max_features=1, n_estimators=5; total time=   0.0s
# [CV 2/5] END .................max_features=1, n_estimators=5; total time=   0.0s
# [CV 3/5] END .................max_features=1, n_estimators=5; total time=   0.0s
# [CV 4/5] END .................max_features=1, n_estimators=5; total time=   0.0s
# [CV 5/5] END .................max_features=1, n_estimators=5; total time=   0.0s
# [CV 1/5] END ................max_features=1, n_estimators=10; total time=   0.0s
# [CV 2/5] END ................max_features=1, n_estimators=10; total time=   0.0s
# [CV 3/5] END ................max_features=1, n_estimators=10; total time=   0.0s
# [CV 4/5] END ................max_features=1, n_estimators=10; total time=   0.0s
# [CV 5/5] END ................max_features=1, n_estimators=10; total time=   0.0s
# [CV 1/5] END ................max_features=1, n_estimators=15; total time=   0.0s
# ...

# %%
pred2 = model2_gs.predict(x_val)

# %%
print(cla)

# %% [markdown]
# ### (2) max_features 튜닝

# %%
params={'max_features':range(1,21)}

# %%
model2=RandomForestClassifier()
model2_gs=GridSearchCV(model2,params,cv=5,verbose=3)

# %%
model2_gs.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5] END .................................max_features=1; total time=   0.4s
# [CV 2/5] END .................................max_features=1; total time=   0.3s
# [CV 3/5] END .................................max_features=1; total time=   0.3s
# [CV 4/5] END .................................max_features=1; total time=   0.4s
# [CV 5/5] END .................................max_features=1; total time=   0.3s
# [CV 1/5] END .................................max_features=2; total time=   0.5s
# [CV 2/5] END .................................max_features=2; total time=   0.4s
# [CV 3/5] END .................................max_features=2; total time=   0.5s
# [CV 4/5] END .................................max_features=2; total time=   0.5s
# [CV 5/5] END .................................max_features=2; total time=   0.5s
# [CV 1/5] END .................................max_features=3; total time=   0.5s
# ...

# %%
pred2 = model2_gs.predict(x_val)

# %%
print(classification_report(y_val,pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71       769
#            1       0.69      0.72      0.70       731
#
#     accuracy                           0.71      1500
#    macro avg       0.71      0.71      0.71      1500
# weighted avg       0.71      0.71      0.71      1500

# %% [markdown]
# * 변수 중요도

# %% [markdown]
# ### (1) n_estimators

# %%
params={'n_estimators': range(5,201,5)}

# %%
model2=RandomForestClassifier()

# %%
model2_gs=GridSearchCV(model2,params,cv=5)

# %%
model2_gs.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'n_estimators': range(5, 201, 5)})

# %%
model2_gs.best_params_,model2_gs.best_score_ #트리 60개 만들면 좋아
# Out:
# ({'n_estimators': 165}, 0.6922857142857144)

# %%
pred2 = model2_gs.predict(x_val)

# %%
print(classification_report(y_val,pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.71      0.71       769
#            1       0.70      0.70      0.70       731
#
#     accuracy                           0.71      1500
#    macro avg       0.71      0.71      0.71      1500
# weighted avg       0.71      0.71      0.71      1500

# %% [markdown]
# + 튜닝 결과를 그래프로 그려보기

# %%
#튜닝 결과를 데이터 프레임으로 저장하기
result=pd.DataFrame(model2_gs.cv_results_)
result.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.066113      0.008196         0.009258        0.005536
# 1       0.077441      0.011424         0.008685        0.003509
# 2       0.113975      0.010059         0.010428        0.004961
# 3       0.148323      0.010627         0.011511        0.001461
# 4       0.238919      0.053003         0.019159        0.004475
#
#   param_n_estimators                params  split0_test_score  \
# 0                  5   {'n_estimators': 5}           0.614286
# 1                 10  {'n_estimators': 10}           0.632857
# 2                 15  {'n_estimators': 15}           0.634286
# 3                 20  {'n_estimators': 20}           0.652857
# 4                 25  {'n_estimators': 25}           0.657143
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.648571           0.638571           0.655714           0.644286
# ...

# %%
temp=result.loc[:,['param_n_estimators','mean_test_score']]
temp.head()
# Out:
#   param_n_estimators  mean_test_score
# 0                  5         0.640286
# 1                 10         0.650571
# 2                 15         0.657714
# 3                 20         0.668571
# 4                 25         0.669429

# %%
plt.figure(figsize=(12,8))
plt.plot('param_n_estimators','mean_test_score',data=temp) #트리의 개수는 100-200정도면 충분해
plt.grid()
plt.show()

# %% [markdown]
# 경향을 보는게 중요
# 데이터 건수를 늘려도 n_estimators는 수평 유지 -> 트리를 많이 만들어도 의미 없음, 적당히 만들자 -> elbow method
# 경향을 그려서 꼭 확인하자
# RF는 트리가 많아진다고 모델이 복잡하지 않음 -> 오히려 트리가 많으면 과적합을 방지함
