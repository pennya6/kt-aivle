# %% [markdown]
# # Regression 종합실습 : Car seat sales
# 유아용 카시트 매출액을 예측해 봅시다.

# %% [markdown]
# * 카시트에 대해서 지역 매장 별 매출액을 예측하고자 합니다.

# %% [markdown]
# ![](https://cdn.images.express.co.uk/img/dynamic/24/590x/child-car-seat-986556.jpg?r=1532946857754)

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### (1) Import

# %%
#라이브러리들을 불러오자.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

import warnings    # 경고메시지 제외
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### (2) Data Loading

# %%
data_path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Carseats.csv'
data = pd.read_csv(data_path)

# %% [markdown]
# **변수설명**
# > * Sales - 각 지역 판매량(단위 : 1000개) <== Target
# * CompPrice - 각 지역 경쟁사 가격
# * Income - 각 지역 평균 소득수준(단위 : 1000달러)
# * Advertising - 각 지역, 회사의 광고 예산(단위 : 1000달러)
# * Population - 지역 인구수(단위 : 1000명)
# * Price - 자사 지역별 판매가격
# * ShelveLoc - 진열상태
# * Age - 지역 인구의 평균 연령
# * Education - 각 지역 교육수준 레벨
# * Urban - 매장 도시 지역 여부
# * US - 매장이 미국에 있는지 여부

# %% [markdown]
# ## 2.데이터 이해

# %% [markdown]
# * 둘러보기

# %%
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US
# 0         17   Yes  Yes
# 1         10   Yes  Yes
# 2         12   Yes  Yes
# 3         14   Yes  Yes
# 4         13   Yes   No

# %%
data.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
#
#                   Age  Education
# Sales       -0.231815  -0.051955
# CompPrice   -0.100239   0.025197
# Income      -0.004670  -0.056855
# Advertising -0.004557  -0.033594
# Population  -0.042663  -0.106378
# Price       -0.102177   0.011747
# ...

# %% [markdown]
# ## 3.데이터 준비

# %% [markdown]
# ### (1) 데이터 정리

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
data.isna().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %% [markdown]
# ### (2) 데이터분할1 : x, y 나누기

# %%
target='Sales'
x=data.drop(target,axis=1)
y=data.loc[:,target]

# %% [markdown]
# ### (3) NA 조치

# %% [markdown]
# ### (4) 가변수화

# %%
x_dummy=pd.get_dummies(x,drop_first=True)

# %%
x_dummy
# Out:
#      CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0          138      73           11         276    120   42         17
# 1          111      48           16         260     83   65         10
# 2          113      35           10         269     80   59         12
# 3          117     100            4         466     97   55         14
# 4          141      64            3         340    128   38         13
# ..         ...     ...          ...         ...    ...  ...        ...
# 395        138     108           17         203    128   33         14
# 396        139      23            3          37    120   55         11
# 397        162      26           12         368    159   40         18
# 398        100      79            7         284     95   50         12
# 399        134      37            0          27    120   49         16
#
#      ShelveLoc_Good  ShelveLoc_Medium  Urban_Yes  US_Yes
# 0                 0                 0          1       1
# ...

# %% [markdown]
# ### (5) 데이터분할2 : train : validation 나누기

# %%
x_train,x_val,y_train,y_val=train_test_split(x_dummy,y,test_size=0.3,random_state=2022)

# %% [markdown]
# ### (6) Scaling
# KNN 알고리즘을 적용하기 위해서는 스케일링을 해야 합니다.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_train_s1=scaler.fit_transform(x_train)
x_val_s1=scaler.transform(x_val)

# %%
from sklearn.preprocessing import StandardScaler
scaler2=StandardScaler()
x_train_s2=scaler2.fit_transform(x_train)
x_val_s2=scaler2.transform(x_val)

# %% [markdown]
# ## 4.모델링 : 선형회귀
#
# * 변수를 조절하며 최소 2개 이상의 모델을 생성하고 예측하고 평가해 봅시다.

# %%
data.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
# Education   -0.051955   0.025197 -0.056855    -0.033594   -0.106378  0.011747
#
#                   Age  Education
# Sales       -0.231815  -0.051955
# CompPrice   -0.100239   0.025197
# Income      -0.004670  -0.056855
# Advertising -0.004557  -0.033594
# Population  -0.042663  -0.106378
# Price       -0.102177   0.011747
# ...

# %% [markdown]
# #### 모델1

# %%
# 모델링용
from sklearn.linear_model import LinearRegression

# 회귀모델 평가용
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
def linear(features):
    features=features
    x_train_1=x_train[features]
    x_val_1=x_val[features]
    linear1=LinearRegression()
    linear1.fit(x_train_1,y_train)
    print(linear1.coef_,linear1.intercept_)
    pred=linear1.predict(x_val_1)
    #RMSE, MAE, MAPE
    print("RMSE:",mean_squared_error(y_val,pred,squared=False))
    print("MAE:",mean_absolute_error(y_val,pred)) #평균오차
    print("MAPE:",mean_absolute_percentage_error(y_val,pred)) #평균오차율
    print('정확도:',1-mean_absolute_percentage_error(y_val,pred))

# %%
linear(['Price'])
# Out:
# [-0.04635436] 12.964838899123844
# RMSE: 2.588984159746482
# MAE: 2.1228736535124924
# MAPE: 0.7488971847312499
# 정확도: 0.2511028152687501

# %% [markdown]
# #### 모델2

# %%
linear(['Price','Advertising'])
# Out:
# [-0.04834065  0.13467122] 12.32023115412376
# RMSE: 2.508280481191849
# MAE: 1.9751678255116005
# MAPE: 0.6747029454297064
# 정확도: 0.32529705457029356

# %% [markdown]
# #### 모델3

# %%
linear(['Price','Advertising','Age','Income'])
# Out:
# [-0.05020252  0.12991273 -0.04606135  0.01368291] 14.082313170839555
# RMSE: 2.3675795840013296
# MAE: 1.900877101914259
# MAPE: 0.6142527193972739
# 정확도: 0.3857472806027261

# %% [markdown]
# #### 모델4

# %%
x_train.columns
# Out:
# Index(['CompPrice', 'Income', 'Advertising', 'Population', 'Price', 'Age',
#        'Education', 'ShelveLoc_Good', 'ShelveLoc_Medium', 'Urban_Yes',
#        'US_Yes'],
#       dtype='object')

# %%
linear(['CompPrice', 'Income', 'Advertising', 'Population', 'Price', 'Age',
       'Education', 'ShelveLoc_Good', 'ShelveLoc_Medium', 'Urban_Yes',
       'US_Yes'])
# Out:
# [ 9.07529162e-02  1.50107692e-02  1.29632695e-01 -2.40199333e-04
#  -9.20716371e-02 -4.50122718e-02 -1.10739568e-02  4.82206767e+00
#   1.94996860e+00  9.28393738e-02 -2.68465709e-01] 5.6110258378122895
# RMSE: 1.0241647217116308
# MAE: 0.8163852580798341
# MAPE: 0.2116929520288113
# 정확도: 0.7883070479711887

# %% [markdown]
# ## 5.모델링 : KNN
#
# * 하이퍼파라미터를 조절하며 모델을 최소 3가지 이상 생성하시오.

# %% [markdown]
# #### 모델1

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
x_train_s1.shape[0]
# Out:
# 280

# %%
import math

# %%
# neighbors 보통 train의 루트
x=int(math.sqrt(x_train_s1.shape[0]))

# %%
KNN=KNeighborsRegressor(n_neighbors=x,metric='euclidean')
KNN.fit(x_train_s1,y_train)
pred=KNN.predict(x_val_s1)
print("RMSE:",mean_squared_error(y_val,pred,squared=False))
print("MAE:",mean_absolute_error(y_val,pred)) #평균오차
print("MAPE:",mean_absolute_percentage_error(y_val,pred)) #평균오차율
# Out:
# RMSE: 2.4230093109795825
# MAE: 2.001
# MAPE: 0.7454612993743849

# %% [markdown]
# #### 모델2

# %%
KNN=KNeighborsRegressor(n_neighbors=x,metric='manhattan')
KNN.fit(x_train_s1,y_train)
pred=KNN.predict(x_val_s1)
print("RMSE:",mean_squared_error(y_val,pred,squared=False))
print("MAE:",mean_absolute_error(y_val,pred)) #평균오차
print("MAPE:",mean_absolute_percentage_error(y_val,pred)) #평균오차율
# Out:
# RMSE: 2.3680149461429187
# MAE: 1.9468229166666664
# MAPE: 0.6858931190449252

# %% [markdown]
# #### 모델3

# %%
KNN=KNeighborsRegressor(n_neighbors=x,metric='euclidean')
KNN.fit(x_train_s2,y_train)
pred=KNN.predict(x_val_s2)
print("RMSE:",mean_squared_error(y_val,pred,squared=False))
print("MAE:",mean_absolute_error(y_val,pred)) #평균오차
print("MAPE:",mean_absolute_percentage_error(y_val,pred)) #평균오차율
# Out:
# RMSE: 2.224773407674317
# MAE: 1.8155052083333336
# MAPE: 0.6309173741362077

# %%
KNN=KNeighborsRegressor(n_neighbors=x,metric='manhattan')
KNN.fit(x_train_s2,y_train)
pred=KNN.predict(x_val_s2)
print("RMSE:",mean_squared_error(y_val,pred,squared=False))
print("MAE:",mean_absolute_error(y_val,pred)) #평균오차
print("MAPE:",mean_absolute_percentage_error(y_val,pred)) #평균오차율
# Out:
# RMSE: 2.272098685830138
# MAE: 1.8297239583333331
# MAPE: 0.6381671059389517

# %% [markdown]
# 과연 몇개의 feature들만 한다면?

# %% [markdown]
# ## 6.성능비교
