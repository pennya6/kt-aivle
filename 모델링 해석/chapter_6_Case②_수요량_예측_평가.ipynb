# %% [markdown]
# # 수요량 예측 평가

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### 1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore')

# %%
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import *

import tensorflow.keras as keras
from keras.models import Model, Sequential
from keras.layers import Input, Dense, LSTM
from keras.backend import clear_session

# %% [markdown]
# ### 2) 데이터 로딩

# %%
data = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/retail_demand_simple.csv")
data['date'] = pd.to_datetime(data['date'])
data.head()
# Out:
#         date  sales  tot_sales  weekday  month     y
# 0 2013-01-01     65        388        1      1  53.0
# 1 2013-01-02     71        371        2      1  68.0
# 2 2013-01-03     53        434        3      1  77.0
# 3 2013-01-04     68        465        4      1  79.0
# 4 2013-01-05     77        527        5      1  44.0

# %% [markdown]
# * 변수 설명

# %% [markdown]
# |	칼럼명	|	설명	|
# |	-----	|	-----	|
# |	date	|	날짜	|
# |	sales	|	A매장 B품목의 판매량	|
# |	tot_sales	|	회사 전체 B품목의 판매량 |
# |	weekday	|	주(1~53) |
# |	month	|	월 |
# |	y	|	2일후 판매량 |

# %%
data.shape
# Out:
# (1824, 6)

# %% [markdown]
# ### 3) 필요 함수 생성

# %% [markdown]
# * 2차원 --> 3차원 구조로 변환

# %%
def temporalize(X, y, timestep):
    output_X = []
    output_y = []
    for i in range(len(X) - timestep + 1):
        t = []
        for j in range(timestep):
            t.append(X[[(i + j)], :])
        output_X.append(t)
        output_y.append(y[i + timestep - 1])
    return np.squeeze(np.array(output_X)), np.array(output_y)

# %% [markdown]
# ## 2.데이터 탐색

# %% [markdown]
# * 전 기간 판매량 그래프

# %%
plt.figure(figsize = (20,8))
sns.lineplot('date', 'sales', data = data)
plt.grid()
plt.show()

# %% [markdown]
# * 4주간의 판매량 그래프

# %%
temp = data[:28]
plt.figure(figsize = (20,8))
sns.lineplot('date', 'sales', data = temp, marker = 'o')
plt.grid()
plt.show()

# %% [markdown]
# ## 3.데이터 준비

# %% [markdown]
# ### 1) 불필요한 변수 제거

# %%
# datetime 제거
drop_cols = ['date']
data.drop(drop_cols, axis = 1, inplace = True)

# %% [markdown]
# ### 2) 가변수화

# %%
data2 = pd.get_dummies(data, columns = ['weekday','month'])

# %% [markdown]
# ### 3) 데이터 분할

# %% [markdown]
# * x, y 분할

# %%
target = 'y'
x = data2.drop(target, axis = 1)
y = data2[[target]]

# %%
x.shape, y.shape
# Out:
# ((1824, 21), (1824, 1))

# %% [markdown]
# * train, validation 분할

# %%
# 최근 60일 : validation set, 나머지 : train set
n = 60

# 분석단위 : 10일간의 판매 데이터를 분석해서 이틀 후 판매량 예측
timesteps = 20

x_train, x_val = x[:-1*n], x[(-1*n - timesteps+1):]
y_train, y_val = y[:-1*n], y[(-1*n - timesteps+1):]

# %%
x_train.shape, y_train.shape
# Out:
# ((1764, 21), (1764, 1))

# %%
x_val.shape, y_val.shape
# Out:
# ((79, 21), (79, 1))

# %% [markdown]
# ### 4) 스케일링

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_x = MinMaxScaler()
x_train_s = scaler_x.fit_transform(x_train)
x_val_s = scaler_x.transform(x_val)

# %%
scaler_y = MinMaxScaler()
y_train_s = scaler_y.fit_transform(y_train)
y_val_s = scaler_y.transform(y_val)

# %% [markdown]
# ### 5) 3차원 구조로 변환

# %%
x_train_s3, y_train_s3 = temporalize(x_train_s, y_train_s, timesteps)
x_val_s3, y_val_s3 = temporalize(x_val_s, y_val_s, timesteps)

# %%
x_train_s3.shape, y_train_s3.shape
# Out:
# ((1745, 20, 21), (1745, 1))

# %%
x_val_s3.shape, y_val_s3.shape
# Out:
# ((60, 20, 21), (60, 1))

# %% [markdown]
# ## 4.모델링
# * 시계열 예측을 위한 LSTM 모델링 수행

# %% [markdown]
# ### 1) 모델 구조

# %%
nfeatures = x_train_s3.shape[2]

# %%
clear_session() 

model = Sequential([
    LSTM(32, input_shape=[timesteps, nfeatures], return_sequences = True),
    LSTM(8, return_sequences = False),
    Dense(8, activation="relu"),
    Dense(1),
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20, 32)            6912
#
#  lstm_1 (LSTM)               (None, 8)                 1312
#
#  dense (Dense)               (None, 8)                 72
#
#  dense_1 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 8,305
# Trainable params: 8,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 2) 컴파일 및 학습

# %%
model.compile(optimizer= 'adam', loss='mse')
history = model.fit(x_train_s3, y_train_s3, 
                    epochs=40, batch_size = 64,
                    validation_split=.2, ).history
# Out:
# Epoch 1/40
# 22/22 [==============================] - 13s 83ms/step - loss: 0.0277 - val_loss: 0.0226
# Epoch 2/40
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0122 - val_loss: 0.0152
# Epoch 3/40
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0108 - val_loss: 0.0151
# Epoch 4/40
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0102 - val_loss: 0.0137
# Epoch 5/40
# 22/22 [==============================] - 0s 20ms/step - loss: 0.0096 - val_loss: 0.0123
# Epoch 6/40
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0089 - val_loss: 0.0121
# Epoch 7/40
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0084 - val_loss: 0.0105
# Epoch 8/40
# 22/22 [==============================] - 0s 12ms/step - loss: 0.0077 - val_loss: 0.0092
# Epoch 9/40
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0070 - val_loss: 0.0085
# Epoch 10/40
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0065 - val_loss: 0.0078
# Epoch 11/40
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0062 - val_loss: 0.0079
# Epoch 12/40
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0060 - val_loss: 0.0078
# Epoch 13/40
# 22/22 [==============================] - 0s 16ms/step - loss: 0.0058 - val_loss: 0.0068
# Epoch 14/40
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0078
# Epoch 15/40
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0057 - val_loss: 0.0070
# Epoch 16/40
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0056 - val_loss: 0.0071
# Epoch 17/40
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0053 - val_loss: 0.0064
# Epoch 18/40
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0050 - val_loss: 0.0061
# Epoch 19/40
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0060
# Epoch 20/40
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0049 - val_loss: 0.0061
# Epoch 21/40
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0048 - val_loss: 0.0058
# Epoch 22/40
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 23/40
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0043 - val_loss: 0.0054
# Epoch 24/40
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0043 - val_loss: 0.0053
# Epoch 25/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0041 - val_loss: 0.0050
# Epoch 26/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0053
# Epoch 27/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0058
# Epoch 28/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0047
# Epoch 29/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0049
# Epoch 30/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0048
# Epoch 31/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 32/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0049
# Epoch 33/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 34/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0048
# Epoch 35/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0048
# Epoch 36/40
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0036 - val_loss: 0.0049
# Epoch 37/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0048
# Epoch 38/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0054
# Epoch 39/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0050
# Epoch 40/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0050

# %%
plt.plot(history['loss'], label = 'train_err')
plt.plot(history['val_loss'], label = 'val_err')

plt.xlabel('epochs')
plt.ylabel('err')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 2) 예측 및 평가
# * validation set으로 예측하고 평가하시오.

# %%
pred = model.predict(x_val_s3)

# %%
# 판매량으로 환원
y_val_r = scaler_y.inverse_transform(y_val_s3)
pred_r = scaler_y.inverse_transform(pred)

# 실판매량과 예측 판매량 비교 그래프
plt.figure(figsize = (12,6))
plt.plot(y_val_r, label = 'actual')
plt.plot(pred_r, label = 'predicted')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# * MAE

# %%
mean_absolute_error(y_val_r, pred_r)
# Out:
# 10.231352615356446

# %% [markdown]
# * 정확도(1-MAPE)

# %%
1- mean_absolute_percentage_error(y_val_r, pred_r)
# Out:
# 0.9060180582203725

# %% [markdown]
# ## 5.비즈니스 기대가치 평가
# * 회귀모델에 대한 비즈니스 평가는 일반화하기 쉽지 않습니다.
# * 예측결과를 가지고 현장에서 어떤 Action이 있는지 파악하고, 그에 맞게 평가 체계를 만들어야 합니다.
# * 여기서는 시계열 데이터 임을 감안하여 평가를 수행해 보도록 하겠습니다.

# %% [markdown]
# ### 1) 재고 시뮬레이터

# %%
def inv_simulator(y, pred, safe_stock) :

    # 시뮬레이션 df 틀 만들기
    temp = pd.DataFrame({'y':y.reshape(-1,), 'pred':pred.reshape(-1,).round()})
    
    temp['base_stock'] = 0
    temp['close_stock'] = 0
    temp['order'] = 0
    temp['receive'] = 0

    # 시뮬레이션

    for i in range(len(temp)-2):  # 발주량은 2일후 판매 예측량에 기초하므로 계산을 위해 마지막 2행 제외
        if i == 0 : #첫 행. 2일 전 데이터가 없으므로, 
            temp.loc[ i ,'receive'] = temp.loc[ i ,'y']  # 입고량은 실판매량으로 계산
            temp.loc[ i ,'base_stock'] = temp.loc[ i ,'receive'] + safe_stock  # 기초재고는 실판매량 + 안전재고로 계산

        elif i == 1 : # 둘째 행, 2일 전 데이터가 없음. 
            temp.loc[ i ,'receive'] = temp.loc[ i ,'y'] # 입고량은 실판매량으로 계산
            temp.loc[ i ,'base_stock'] = temp.loc[ i ,'receive'] + temp.loc[ i-1 ,'close_stock']
        else :      # 나머지 전체 행.
            temp.loc[ i ,'receive'] = temp.loc[ i-2 ,'order']    # 입고량 = 2일전 발주량
            temp.loc[ i ,'base_stock'] = temp.loc[ i ,'receive'] + temp.loc[ i-1 ,'close_stock']  # 기초재고 = 입고량 + 전날 기말재고
        
        # 기말재고 = 기초재고 - 판매량,  만약 0보다 작으면 0으로.
        stock = round(temp.loc[i, 'base_stock'] - temp.loc[i, 'y'])
        temp.loc[i, 'close_stock'] = np.where(stock> 0, stock, 0)
        
        # 발주량 = 2일후 판매예측량 + 안전재고 - 기말재고,  만약 주문량이 0보다 작으면 0
        order = temp.loc[i+2, 'pred'] + safe_stock - temp.loc[i, 'close_stock']
        temp.loc[i, 'order'] = np.where(order>0,order, 0)

    # 기회손실 = 만약 (기초재고 - 실판매량)이 0보다 작으면, 그만큼이 기회손실
    temp['lost'] = np.where((temp['base_stock'] - temp['y'])<0, (temp['base_stock'] - temp['y']),0).round()

    inventory = temp[:len(temp)-2]

    # 측정지표 계산
    DailyStock = ((inventory['base_stock'] + inventory['close_stock'])/2)
    DailyTurnover = (inventory['y'] + inventory['lost']) / DailyStock

    AvgDailyStock = round(DailyStock.mean(),3)
    turnover = round(DailyTurnover.mean(), 3)
    lost_sum = inventory['lost'].sum()

    print(f'일평균 재고량     : {AvgDailyStock}')
    print(f'일평균 재고회전율 : {turnover}')
    print(f'기회손실 수량     : {lost_sum}')

    return inventory, AvgDailyStock, turnover,lost_sum

# %% [markdown]
# ### 2) 예측 결과 시뮬레이션

# %%
result, AvgDailyStock , turnover , lost_sum = inv_simulator(y_val_r, pred_r, 30)
# Out:
# 일평균 재고량     : 90.491
# 일평균 재고회전율 : 1.326
# 기회손실 수량     : -56.0

# %%
result.tail()
# Out:
#         y  pred  base_stock  close_stock  order  receive  lost
# 53   82.0  77.0         112           30   84.0       94   0.0
# 54   80.0  85.0         127           47   74.0       97   0.0
# 55  105.0  84.0         131           26  102.0       84   0.0
# 56   89.0  91.0         100           11  124.0       74   0.0
# 57  101.0  98.0         113           12  131.0      102   0.0

# %%
plt.figure(figsize = (12,8))
plt.plot(result['y'])
plt.plot(result['pred'])
plt.plot(result['close_stock'])
plt.plot(result['lost'])
plt.plot(result['order'])

plt.grid()
plt.show()

# %% [markdown]
# ## 6.실습:
# * 모델을 개선하고 재고회전율로 평가해 봅시다.
