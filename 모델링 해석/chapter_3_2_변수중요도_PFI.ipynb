# %% [markdown]
# # 모델에 대한 설명1_PFI
# * Permutation Feature Importance

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# ### 1) 라이브러리 로딩

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore')

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC, SVR
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.metrics import * 

import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.backend import clear_session

# %% [markdown]
# ### 2) 데이터 로딩

# %%
data = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv')
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# * 변수 설명
#     * crim : 범죄율
#     * zn : 대저택 비율
#     * indus : 산업단지 비율
#     * chas : 찰스 강변 여부
#     * nox : 일산화질소 농도(공기오염도)
#     * rm : 평균 주택당 방 수
#     * age : 30년 이상된 주택 비율
#     * dis : 주요 업무 지역 접근성 지수
#     * rad : 고속도로 접근성 지수
#     * tax  1만 달러당 재산세
#     * ptratio : 교사 1명당 학생수
#     * lstat : 하위계층 비율
#     * black : 흑인비율(원래 숫자를 변형한 것임)
#     * mdev : 타운별 집값 중위수(단위 : 1000달러)

# %% [markdown]
# ### 3) 필요한 함수 생성

# %%
# 변수 중요도 plot
def plot_feature_importance(importance, names, topn = 'all'):
    feature_importance = np.array(importance)
    feature_names = np.array(names)

    data={'feature_names':feature_names,'feature_importance':feature_importance}
    fi_temp = pd.DataFrame(data)

    fi_temp.sort_values(by=['feature_importance'], ascending=False,inplace=True)
    fi_temp.reset_index(drop=True, inplace = True)

    if topn == 'all' :
        fi_df = fi_temp.copy()
    else :
        fi_df = fi_temp.iloc[:topn]

    plt.figure(figsize=(10,8))
    sns.barplot(x='feature_importance', y='feature_names', data = fi_df)

    plt.xlabel('importance')
    plt.ylabel('feature names')
    plt.grid()

    return fi_df

# %% [markdown]
# ## 2.데이터 준비

# %% [markdown]
# ### 1) x, y로 나누기

# %%
target = 'medv'
x = data.drop(target, axis = 1)
y = data.loc[:,target]

# %% [markdown]
# ### 2) 가변수화

# %% [markdown]
# ### 3) train : validation 분할

# %%
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size = .2, random_state = 2022)
x_train.shape
# Out:
# (404, 13)

# %% [markdown]
# ### 4) 스케일링

# %%
scaler = MinMaxScaler()
x_train_s = scaler.fit_transform(x_train)
x_val_s = scaler.transform(x_val)

# %% [markdown]
# ## 3.Permutation Feature Importance
#
# * model1 : SVM
# * model2 : DL

# %%
from sklearn.inspection import permutation_importance

# %% [markdown]
# ### 1) SVM 모델

# %%
model1 = SVR()
model1.fit(x_train_s, y_train)
# Out:
# SVR()

# %% [markdown]
# * permutation feature importance 구하기

# %%
pfi1 = permutation_importance(model1, x_val_s, y_val, n_repeats=10, scoring = 'r2', random_state=2022)

# %%
pfi1
# Out:
# {'importances_mean': array([0.00945374, 0.02086725, 0.03294957, 0.03386631, 0.02895424,
#         0.14430705, 0.05740539, 0.01810863, 0.02795648, 0.06606279,
#         0.07908538, 0.01881995, 0.24118307]),
#  'importances_std': array([0.00267741, 0.00728268, 0.00678155, 0.01320997, 0.00993524,
#         0.01427471, 0.01680534, 0.01403577, 0.01069404, 0.01817568,
#         0.01402084, 0.01418209, 0.02658648]),
#  'importances': array([[0.01202894, 0.0107116 , 0.00956138, 0.01383913, 0.00721868,
#          0.00671367, 0.0131682 , 0.00643447, 0.00687128, 0.00799003],
#         [0.01532828, 0.02365336, 0.031247  , 0.01905323, 0.03024437,
#          0.01534974, 0.02420276, 0.0057787 , 0.01862319, 0.02519188],
#         [0.01920832, 0.03288757, 0.03588737, 0.03716216, 0.03562646,
#          0.03493756, 0.03327672, 0.02338953, 0.0322704 , 0.04484963],
#         [0.04604279, 0.02896597, 0.02650305, 0.06144869, 0.03828285,
#          0.02357206, 0.03553383, 0.00886427, 0.03593179, 0.03351783],
#         [0.02155195, 0.02763862, 0.02381862, 0.04908277, 0.04350943,
#          0.01898032, 0.0253759 , 0.0174404 , 0.03515601, 0.02698836],
#         [0.14934697, 0.14898562, 0.13328107, 0.13896236, 0.12637877,
#          0.16767923, 0.16166089, 0.15589054, 0.12170238, 0.13918266],
#         [0.04145372, 0.06286162, 0.07553061, 0.08115248, 0.05905493,
# %% [markdown]
# * feature별 Score 분포

# %%
plt.figure(figsize = (10,8))
for i,vars in enumerate(list(x)) :
    sns.kdeplot(pfi1.importances[i], label = vars)
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# lstat가 가장 높은 성능
# rm이 2번째

# %%
sorted_idx = pfi1.importances_mean.argsort()
plt.figure(figsize = (10, 8))
plt.boxplot(pfi1.importances[sorted_idx].T, vert=False, labels=x.columns[sorted_idx])
plt.axvline(0, color = 'r')
plt.grid()
plt.show()

# %% [markdown]
# 0을 기준으로 lstat의 분포
# crim이 제일 낮음 -> svm은 crim이 낮고 lstat, rm이 높다

# %% [markdown]
# * 평균값으로 변수중요도 그래프 그리기

# %%
result = plot_feature_importance(pfi1.importances_mean, list(x_train)) #svm 모델의 중요도

# %% [markdown]
# ### 2) DL 모델

# %% [markdown]
# * 간단한 DL 모델을 생성해 봅시다.

# %%
x_train_s.shape[1]
# Out:
# 13

# %%
nfeatures = x_train_s.shape[1]
clear_session()

model2 = Sequential([Dense(32, input_shape = [nfeatures,], activation = 'relu'),
                     Dense(8, activation = 'relu'),
                     Dense(1)
                     ])

model2.compile(optimizer = 'adam', loss = 'mse')
history = model2.fit(x_train_s, y_train, epochs = 200, validation_split = .2).history
# Out:
# Epoch 1/200
# 11/11 [==============================] - 1s 18ms/step - loss: 621.7648 - val_loss: 590.0389
# Epoch 2/200
# 11/11 [==============================] - 0s 3ms/step - loss: 616.0853 - val_loss: 582.5733
# Epoch 3/200
# 11/11 [==============================] - 0s 4ms/step - loss: 607.6326 - val_loss: 572.9642
# Epoch 4/200
# 11/11 [==============================] - 0s 3ms/step - loss: 597.1895 - val_loss: 561.3009
# Epoch 5/200
# 11/11 [==============================] - 0s 3ms/step - loss: 584.1037 - val_loss: 546.5146
# Epoch 6/200
# 11/11 [==============================] - 0s 3ms/step - loss: 568.1542 - val_loss: 528.4313
# Epoch 7/200
# 11/11 [==============================] - 0s 3ms/step - loss: 548.2545 - val_loss: 506.6877
# Epoch 8/200
# 11/11 [==============================] - 0s 3ms/step - loss: 524.3181 - val_loss: 480.0538
# Epoch 9/200
# 11/11 [==============================] - 0s 4ms/step - loss: 494.7330 - val_loss: 447.4409
# Epoch 10/200
# 11/11 [==============================] - 0s 3ms/step - loss: 459.3514 - val_loss: 409.7092
# Epoch 11/200
# 11/11 [==============================] - 0s 3ms/step - loss: 419.1417 - val_loss: 366.8333
# Epoch 12/200
# 11/11 [==============================] - 0s 3ms/step - loss: 373.4612 - val_loss: 319.2513
# Epoch 13/200
# 11/11 [==============================] - 0s 4ms/step - loss: 324.4509 - val_loss: 270.3790
# Epoch 14/200
# 11/11 [==============================] - 0s 4ms/step - loss: 274.8909 - val_loss: 223.4907
# Epoch 15/200
# 11/11 [==============================] - 0s 4ms/step - loss: 228.5136 - val_loss: 183.1802
# Epoch 16/200
# 11/11 [==============================] - 0s 5ms/step - loss: 191.6187 - val_loss: 152.9534
# Epoch 17/200
# 11/11 [==============================] - 0s 5ms/step - loss: 162.9940 - val_loss: 133.5377
# Epoch 18/200
# 11/11 [==============================] - 0s 3ms/step - loss: 146.5103 - val_loss: 122.8086
# Epoch 19/200
# 11/11 [==============================] - 0s 3ms/step - loss: 137.0810 - val_loss: 116.3358
# Epoch 20/200
# 11/11 [==============================] - 0s 3ms/step - loss: 130.1300 - val_loss: 111.3672
# Epoch 21/200
# 11/11 [==============================] - 0s 6ms/step - loss: 124.8868 - val_loss: 107.1606
# Epoch 22/200
# 11/11 [==============================] - 0s 4ms/step - loss: 119.8879 - val_loss: 103.3893
200
# 11/11 [==============================] - 0s 3ms/step - loss: 22.9285 - val_loss: 16.2752
# Epoch 121/200
# 11/11 [==============================] - 0s 4ms/step - loss: 22.6307 - val_loss: 16.3303
# Epoch 122/200
# 11/11 [==============================] - 0s 4ms/step - loss: 22.6388 - val_loss: 16.0912
# Epoch 123/200
# 11/11 [==============================] - 0s 3ms/step - loss: 22.4769 - val_loss: 16.0443
# Epoch 124/200
# 11/11 [==============================] - 0s 3ms/step - loss: 22.2968 - val_loss: 16.1072
# Epoch 125/200
# 11/11 [==============================] - 0s 3ms/step - loss: 22.2043 - val_loss: 15.8643
# Epoch 126/200
# 11/11 [==============================] - 0s 3ms/step - loss: 22.3233 - val_loss: 15.8850
# Epoch 127/200
# 11/11 [==============================] - 0s 4ms/step - loss: 22.3451 - val_loss: 15.7271
# Epoch 128/200
# 11/11 [==============================] - 0s 3ms/step - loss: 22.1764 - val_loss: 15.7534
# Epoch 129/200
# 11/11 [==============================] - 0s 3ms/step - loss: 21.9922 - val_loss: 15.7015
# Epoch 130/200
# 11/11 [==============================] - 0s 4ms/step - loss: 22.1697 - val_loss: 15.8371
# Epoch 131/200
# 11/11 [==============================] - 0s 4ms/step - loss: 22.0996 - val_loss: 15.7083
# Epoch 132/200
# 11/11 [==============================] - 0s 4ms/step - loss: 21.9484 - val_loss: 15.6609
# Epoch 133/200
# 11/11 [==============================] - 0s 4ms/step - loss: 21.7545 - val_loss: 15.6353
# Epoch 134/200
# 11/11 [==============================] - 0s 4ms/step - loss: 21.8723 - val_loss: 15.6288
# Epoch 135/200
# 11/11 [==============================] - 0s 3ms/step - loss: 21.7863 - val_loss: 15.5022
# Epoch 136/200
# 11/11 [==============================] - 0s 3ms/step - loss: 21.5794 - val_loss: 15.5260
# Epoch 137/200
# 11/11 [==============================] - 0s 3ms/step - loss: 21.5481 - val_loss: 15.5581
# Epoch 138/200
# 11/11 [==============================] - 0s 3ms/step - loss: 22.0536 - val_loss: 15.6709
# Epoch 139/200
# 11/11 [==============================] - 0s 3ms/step - loss: 21.6354 - val_loss: 16.1132
# Epoch 140/200
# 11/11 [==============================] - 0s 4ms/step - loss: 21.5862 - val_loss: 15.5385
# Epoch 141/200
# 11/11 [==============================] - 0s 3ms/step - loss: 21.4845 - val_loss: 15.5577
# Epoch 142/200
# 11/11 [==============================] - 0s 4ms/step - loss: 21.4100 - val_loss: 15.3189
# Epoch 143/200
# 11/11 [==============================] - 0s 3ms/step - loss: 21.2581 - val_loss: 15.4852
# Epoch 144/200
# 11/11 [==============================] - 0s 3ms/step - loss: 21.3462 - val_loss: 15.1701
# Epoch 145/200
# 11/11 [==============================] - 0s 4ms/step - loss: 21.1429 - val_loss: 15.1883
# Epoch 146/200
# 11/11 [==============================] - 0s 3ms/step - loss: 21.2610 - val_loss: 15.0944
# Epoch 147/200
# 11/11 [==============================] - 0s 4ms/step - loss: 21.2194 - val_loss: 15.2157
# Epoch 148/200
# 11/11 [==============================] - 0s 4ms/step - loss: 21.0173 - val_loss: 15.0564
# Epoch 149/200
# 11/11 [==============================] - 0s 3ms/step - loss: 21.0045 - val_loss: 15.0313
# Epoch 150/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.9436 - val_loss: 14.9759
# Epoch 151/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.9244 - val_loss: 15.0409
# Epoch 152/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.9134 - val_loss: 14.9544
# Epoch 153/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.7947 - val_loss: 14.9195
# Epoch 154/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.9182 - val_loss: 14.9456
# Epoch 155/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.8356 - val_loss: 14.8992
# Epoch 156/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.6757 - val_loss: 14.8991
# Epoch 157/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.6941 - val_loss: 14.8545
# Epoch 158/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.7488 - val_loss: 14.9628
# Epoch 159/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.7658 - val_loss: 14.8905
# Epoch 160/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.6015 - val_loss: 15.0692
# Epoch 161/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.8639 - val_loss: 14.9974
# Epoch 162/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.6763 - val_loss: 14.9696
# Epoch 163/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.6116 - val_loss: 14.8045
# Epoch 164/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.4406 - val_loss: 14.7920
# Epoch 165/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.3261 - val_loss: 14.7724
# Epoch 166/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.3375 - val_loss: 14.8279
# Epoch 167/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.4746 - val_loss: 14.7650
# Epoch 168/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.2600 - val_loss: 14.7918
# Epoch 169/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.4085 - val_loss: 14.8945
# Epoch 170/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.1750 - val_loss: 14.8178
# Epoch 171/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.2854 - val_loss: 14.9150
# Epoch 172/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.0754 - val_loss: 14.9287
# Epoch 173/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.3710 - val_loss: 14.7838
# Epoch 174/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.0621 - val_loss: 14.6659
# Epoch 175/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.0638 - val_loss: 14.6602
# Epoch 176/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.0645 - val_loss: 14.6823
# Epoch 177/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.0862 - val_loss: 14.6517
# Epoch 178/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.4351 - val_loss: 15.2761
# Epoch 179/200
# 11/11 [==============================] - 0s 3ms/step - loss: 20.0067 - val_loss: 14.7079
# Epoch 180/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.9463 - val_loss: 14.6612
# Epoch 181/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.8583 - val_loss: 14.6592
# Epoch 182/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.9710 - val_loss: 14.5919
# Epoch 183/200
# 11/11 [==============================] - 0s 4ms/step - loss: 19.8392 - val_loss: 14.5962
# Epoch 184/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.8268 - val_loss: 14.5909
# Epoch 185/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.7334 - val_loss: 14.5256
# Epoch 186/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.8232 - val_loss: 14.5411
# Epoch 187/200
# 11/11 [==============================] - 0s 4ms/step - loss: 19.7762 - val_loss: 14.4878
# Epoch 188/200
# 11/11 [==============================] - 0s 4ms/step - loss: 19.9673 - val_loss: 14.5498
# Epoch 189/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.6997 - val_loss: 14.4895
# Epoch 190/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.6872 - val_loss: 14.4544
# Epoch 191/200
# 11/11 [==============================] - 0s 4ms/step - loss: 20.0472 - val_loss: 14.5893
# Epoch 192/200
# 11/11 [==============================] - 0s 4ms/step - loss: 19.6873 - val_loss: 14.4967
# Epoch 193/200
# 11/11 [==============================] - 0s 4ms/step - loss: 19.5066 - val_loss: 14.4431
# Epoch 194/200
# 11/11 [==============================] - 0s 4ms/step - loss: 19.5061 - val_loss: 14.4559
# Epoch 195/200
# 11/11 [==============================] - 0s 4ms/step - loss: 19.5408 - val_loss: 14.3846
# Epoch 196/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.5136 - val_loss: 14.4650
# Epoch 197/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.4809 - val_loss: 14.4796
# Epoch 198/200
# 11/11 [==============================] - 0s 3ms/step - loss: 19.4458 - val_loss: 14.4721
# Epoch 199/200
# 11/11 [==============================] - 0s 5ms/step - loss: 19.4663 - val_loss: 14.3807
# Epoch 200/200
# 11/11 [==============================] - 0s 4ms/step - loss: 19.3574 - val_loss: 14.2816

# %% [markdown]
# * permutation feature importance 구하기
#     * deep learning 모델에 대해서는 명시적으로 scoring = 'r2'을 지정해 줘야 합니다.

# %%
pfi2 = permutation_importance(model2, x_val_s, y_val, n_repeats=10, scoring = 'r2', random_state=2022)

# %%
pfi2

# %% [markdown]
# * feature별 Score 분포

# %%
plt.figure(figsize = (12,8))
for i,vars in enumerate(list(x)) :
    sns.kdeplot(pfi2.importances[i], label = vars)

plt.legend()
plt.show()

# %%
sorted_idx = pfi2.importances_mean.argsort()
plt.figure(figsize = (12,8))
plt.boxplot(pfi2.importances[sorted_idx].T, vert=False, labels=x.columns[sorted_idx])
plt.axvline(0, color = 'r')
plt.grid()
plt.show()

# %% [markdown]
# svm보다 lstat, rm의 영향력이 절대적이다.

# %% [markdown]
# * 평균값으로 변수중요도 그래프 그리기

# %%
result = plot_feature_importance(pfi2.importances_mean, list(x_train))

# %%
from sklearn.metrics import *

# %%
pred1 = model1.predict(x_val_s)
print(r2_score(y_val,pred1))
print(mean_absolute_error(y_val, pred1))
# Out:
# 0.6595120367559157
# 3.2468419828844173

# %%
pred2 = model2.predict(x_val_s)
print(r2_score(y_val,pred2))
print(mean_absolute_error(y_val, pred2))
# Out:
# 0.6239898817924349
# 3.7733876041337546

# %% [markdown]
# ## 4.실습 : 직원 이직 예측모델 변수 중요도 비교

# %% [markdown]
# ### 1) 데이터 준비

# %% [markdown]
# * 데이터 로딩

# %%
# data data
path = "https://raw.githubusercontent.com/DA4BAM/dataset/master/Attrition2.csv"
data = pd.read_csv(path)
data.head(10)
# Out:
#    Attrition  Age              Department  DistanceFromHome  Education  \
# 0          0   28  Research & Development                 1          3
# 1          1   37  Research & Development                 2          2
# 2          0   27  Research & Development                 8          5
# 3          0   18  Research & Development                 1          3
# 4          0   29  Research & Development                 9          3
# 5          0   44  Research & Development                 2          1
# 6          0   41                   Sales                10          2
# 7          0   25                   Sales                18          1
# 8          0   50  Research & Development                 2          3
# 9          0   47                   Sales                 4          2
#
#   EducationField  Gender                 JobRole  JobSatisfaction  \
# 0        Medical  Female      Research Scientist                1
# 1          Other    Male   Laboratory Technician                3
# 2  Life Sciences    Male   Laboratory Technician                3
# 3  Life Sciences  Female   Laboratory Technician                4
# 4  Life Sciences    Male      Research Scientist                3
# 5        Medical    Male  Manufacturing Director                3
# 6  Life Sciences    Male         Sales Executive                4
# 7  Life Sciences    Male         Sales Executive                3
# 8        Medical    Male       Research Director                3
# 9  Life Sciences  Female         Sales Executive                4
#
#   MaritalStatus  MonthlyIncome  NumCompaniesWorked  RelationshipSatisfaction  \
# 0       Married           3591                   1                         3
# 1        Single           2090                   6                         2
# 2       Married           4621                   1                         4
# 3        Single           1611                   1                         3
# 4       Married           2451                   6                         1
# 5        Single          10209                   5                         2
# 6        Single           6230                   7                         4
# 7       Married           6232                   2                         2
# 8       Married          17639                   5                         4
# 9        Single           4163                   1                         3
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany
# 0                  3                      3                3               3
# 1                  7                      3                3               0
# 2                  3                      4                3               3
# 3                  0                      5                4               0
# 4                  5                      2                2               1
# 5                 16                      2                2               2
# 6                 16                      3                3              14
# 7                  6                      3                2               3
# 8                 30                      3                3               4
# 9                  9                      0                3               9

# %% [markdown]
# |	변수 명	|	내용	|	구분	|
# |	----	|	----	|	----	|
# |	**Attrition**	|	이직여부, Yes = 1 , No = 0	|	**Target**	|
# |	Age	|	나이	|	숫자	|
# |	BusinessTravel	|	출장 빈도(범주)	|		|
# |	Department	|	현 부서	|		|
# |	DistanceFromHome	|	집-직장 거리(마일)	|	숫자	|
# |	Education	|	교육수준(범주)	|	1 Below College, 2 College, 3 Bachelor, 4 Master, 5 Doctor	|
# |	EducationField	|	전공	|		|
# |	EnvironmentSatisfaction	|	근무환경에 대한 만족도(범주)	|	1 Low, 2 Good, 3 Excellent, 4 Outstanding	|
# |	Gender	|	성별	|		|
# |	JobInvolvement	|	직무 적극성(참여도)	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	JobRole	|	직무	|		|
# |	JobSatisfaction	|	직무 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	MaritalStatus	|	결혼상태	|		|
# |	MonthlyIncome	|	월급	|	숫자	|
# |	NumCompaniesWorked	|	현재까지 근무한 회사 수	|	숫자	|
# |	PercentSalaryHike	|	전년대비 급여인상율(%)	|	숫자	|
# |	RelationshipSatisfaction	|	동료와의 관계 만족도	|	1 Low, 2 Medium, 3 High, 4 Very High	|
# |	StockOptionLevel	|	스톡옵션 수준 0~3	|	범주	|
# |	TotalWorkingYears	|	총 근무 연수	|	숫자	|
# |	TrainingTimesLastYear	|	전년 교육훈련 횟수	|	숫자	|
# |	WorkLifeBalance	|	워라밸. 일-삶 균형도	|	1 Bad, 2 Good, 3 Better, 4 Best	|
# |	YearsAtCompany	|	현직장 근무 연수	|	숫자	|
# |	YearsInCurrentRole	|	현직무 연수	|	숫자	|
# |	YearsWithCurrManager	|	현 팀장과 근무한 연수	|	숫자	|

# %%
target = 'Attrition'
x = data.drop(target, axis = 1)
y = data.loc[:, target]

# %%
y.value_counts() / y.shape[0]
# Out:
# 0    0.913043
# 1    0.086957
# Name: Attrition, dtype: float64

# %% [markdown]
# * 가변수화 Dummy Variable

# %%
dummy_vars = ['Education','Department','EducationField','Gender','JobRole','JobSatisfaction','MaritalStatus',
              'RelationshipSatisfaction','WorkLifeBalance'] # 가변수화 대상 변수 이름 리스트 만든다
x = pd.get_dummies(x, columns = dummy_vars, drop_first=True)

# %% [markdown]
# * 데이터 분할
#     * 이미 test set은 분할되어 있다고 가정합니다.
#     * 주어진 데이터를 train set : validation set 으로 분할

# %%
# train_val에서 train : val = 8 : 2
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state = 2022)

# %%
print(x_train.shape, x_val.shape)
# Out:
# (920, 38) (230, 38)

# %% [markdown]
# * class balance를 맞추기 위한 resampling

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()
sm_x_train, sm_y_train = smote.fit_resample(x_train, y_train)

# %% [markdown]
# * 스케일링

# %%
scaler = MinMaxScaler()
sm_x_train_s = scaler.fit_transform(sm_x_train)
x_val_s = scaler.transform(x_val)

# %% [markdown]
# ### 2) 모델링 및 변수 중요도 계산하기
#
# * model1 : SVM
# * model2 : KNN

# %%
from sklearn.inspection import permutation_importance

# %% [markdown]
# #### ① SVM 모델

# %% [markdown]
# * 모델링

# %%
svm=SVC()

# %%
svm.fit(sm_x_train_s,sm_y_train)
# Out:
# SVC()

# %% [markdown]
# * permutation feature importance 구하기

# %%
pfi1 = permutation_importance(svm, x_val_s, y_val, n_repeats=10,random_state=2022)

# %%
plt.figure(figsize = (10,8))
for i,vars in enumerate(list(x)) :
    sns.kdeplot(pfi1.importances[i], label = vars)
plt.grid()
plt.legend()
plt.show()

# %%
sorted_idx = pfi1.importances_mean.argsort()
plt.figure(figsize = (10, 8))
plt.boxplot(pfi1.importances[sorted_idx].T, vert=False, labels=x.columns[sorted_idx])
plt.axvline(0, color = 'r')
plt.grid()
plt.show()

# %% [markdown]
# 마이너스 무엇?
# S-섞은 결과 -> 성능이 .... 마이너스? 빼고 해볼까?

# %% [markdown]
# * 평균값으로 변수중요도 그래프 그리기

# %%
result = plot_feature_importance(pfi1.importances_mean, list(x_train)) #svm 모델의 중요도

# %% [markdown]
# * 예측 및 평가

# %%
pred1=svm.predict(x_val_s)
print(classification_report(y_val,pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       217
#            1       0.50      0.23      0.32        13
#
#     accuracy                           0.94       230
#    macro avg       0.73      0.61      0.64       230
# weighted avg       0.93      0.94      0.93       230

# %% [markdown]
# #### ② KNN 모델

# %% [markdown]
# * 모델링

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(sm_x_train_s,sm_y_train)
# Out:
# KNeighborsClassifier()

# %%
pred2=knn.predict(x_val_s)

# %% [markdown]
# * permutation feature importance 구하기

# %%
pfi1 = permutation_importance(knn, x_val_s, y_val, n_repeats=10,  random_state=2022)

# %% [markdown]
# * feature별 Score 분포

# %%
plt.figure(figsize = (10,8))
for i,vars in enumerate(list(x)) :
    sns.kdeplot(pfi1.importances[i], label = vars)
plt.grid()
plt.legend()
plt.show()

# %%
sorted_idx = pfi1.importances_mean.argsort()
plt.figure(figsize = (10, 8))
plt.boxplot(pfi1.importances[sorted_idx].T, vert=False, labels=x.columns[sorted_idx])
plt.axvline(0, color = 'r')
plt.grid()
plt.show()

# %% [markdown]
# * 평균값으로 변수중요도 그래프 그리기

# %%
result = plot_feature_importance(pfi1.importances_mean, list(x_train)) #svm 모델의 중요도

# %%
print(classification_report(y_val,pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92       217
#            1       0.18      0.46      0.26        13
#
#     accuracy                           0.85       230
#    macro avg       0.57      0.67      0.59       230
# weighted avg       0.92      0.85      0.88       230

# %% [markdown]
# 가장 성능이 좋은 모델의 성능 중요도를 보는것이 중요하다
