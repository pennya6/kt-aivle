# %% [markdown]
# # 11과 이변량분석 종합실습

# %% [markdown]
# ## 환경준비

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as spst
from statsmodels.graphics.mosaicplot import mosaic
import statsmodels.api as sm

# %% [markdown]
# # 1.숫자형 Y : car seat 매출 분석

# %% [markdown]
# * 카시트에 대해서 지역 매장 별 매출액을 예측하고자 합니다.

# %% [markdown]
# ![](https://cdn.images.express.co.uk/img/dynamic/24/590x/child-car-seat-986556.jpg?r=1532946857754)

# %% [markdown]
# |	변수명	|	설명	|	구분	|
# |	----	|	----	|	----	|
# |	Sales 	|	 각 지역 판매량(단위 : 1000개)	|	Target	|
# |	CompPrice 	|	지역별 경쟁사 판매가격(달러)	|	feature	|
# |	Advertising 	|	 각 지역, 회사의 광고 예산(단위 : 1000달러)	|	feature	|
# |	Population 	|	 지역 인구수(단위 : 1000명)	|	feature	|
# |	Price 	|	 자사 지역별 판매가격(달러)	|	feature	|
# |	ShelveLoc 	|	 진열상태	|	feature	|
# |	Age 	|	 지역 인구의 평균 연령	|	feature	|
# |	US 	|	 매장이 미국에 있는지 여부	|	feature	|
# |	Income 	|	 지역 주민 평균 소득	|	feature	|
# |	Urban 	|	 매장이 도시에 있는지 여부	|	feature	|
# |	Education 	|	 지역 주민 평균 교육수준(범주: 11~17)	|	feature	|

# %%
path = 'https://raw.githubusercontent.com/JunhoYu/Data-Analysis/main/Carseats.csv'
data = pd.read_csv(path)
data.drop(['Income', 'Urban', 'Education'],axis = 1, inplace = True)
data.head()
# Out:
#    Sales  CompPrice  Advertising  Population  Price ShelveLoc  Age   US
# 0   9.50        138           11         276    120       Bad   42  Yes
# 1  11.22        111           16         260     83      Good   65  Yes
# 2  10.06        113           10         269     80    Medium   59  Yes
# 3   7.40        117            4         466     97    Medium   55  Yes
# 4   4.15        141            3         340    128       Bad   38   No

# %%
target = 'Sales'

# %% [markdown]
# ### (1) 숫자형(수치형) X --> Y
# * 모든 숫자형 X에 대해서 Y와 비교하여 차트를 그리고 수치화 하시오.
#
# ① 시각화 : scatter, jointplot
# ② 수치화 : 상관분석

# %% [markdown]
# #### ① Advertising -> Sales

# %%
feature='Advertising'

# %% [markdown]
# 1) 시각화 : scatter(regplot), jointplot

# %%
sns.scatterplot(x=data[feature],y=data[target])
# Out:
# <AxesSubplot:xlabel='Advertising', ylabel='Sales'>

# %%
sns.jointplot(x=data[feature],y=data[target])

# %% [markdown]
# + 시각화에서는 관계가 없어 보임

# %% [markdown]
# 2) 수치화 : 상관분석

# %%
data[feature].isna().sum()
# Out:
# 0

# %%
spst.pearsonr(data[feature],data[target])
# Out:
# (0.269506781376902, 4.377677110302732e-08)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# 양의 상관관계가 있다. 그러나 강하지는 않다.

# %% [markdown]
# #### ② Population -> Sales

# %% [markdown]
# 1) 시각화 : scatter(regplot), jointplot

# %%
feature='Population'

# %%
sns.regplot(x=data[feature],y=data[target])
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Sales'>

# %%
sns.jointplot(x=data[feature],y=data[target])

# %% [markdown]
# 2) 수치화 : 상관분석

# %%
spst.pearsonr(data[feature],data[target])
# Out:
# (0.0504709844720392, 0.31398160931903)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# + 관련이 없다.
# + 근데 인구수가 많으면 판매량이 늘어나는것 아닐까? 왜 관련이 없지?

# %% [markdown]
# #### ③ Price -> Sales

# %% [markdown]
# 1) 시각화 : scatter(regplot), jointplot

# %%
feature='Price'

# %%
sns.regplot(x=data[feature],y=data[target])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Sales'>

# %%
sns.jointplot(x=data[feature],y=data[target])

# %% [markdown]
# 2) 수치화 : 상관분석

# %%
spst.pearsonr(data[feature],(data[target]))
# Out:
# (-0.4449507278465726, 7.61818701191294e-21)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
#  + 음의 상관관계가 있다.

# %% [markdown]
# #### ④ Age -> Sales

# %% [markdown]
# 1) 시각화 : scatter(regplot), jointplot

# %%
feature='Age'

# %%
sns.regplot(x=data[feature],y=data[target])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sales'>

# %%
sns.jointplot(x=data[feature],y=data[target])

# %% [markdown]
# 2) 수치화 : 상관분석

# %%
spst.pearsonr(data[feature],data[target])
# Out:
# (-0.2318154396045765, 2.7889498393711916e-06)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# + 연령대(평균연령이 높아질 수록 판매량이 낮아진다.) 관련이 있다. 그러나 강하지 않다.

# %% [markdown]
# #### ⑤ CompPrice -> Sales

# %% [markdown]
# 1) 시각화 : scatter(regplot), jointplot

# %%
feature='CompPrice'

# %%
sns.regplot(x=data[feature],y=data[target])
# Out:
# <AxesSubplot:xlabel='CompPrice', ylabel='Sales'>

# %%
sns.jointplot(x=data[feature],y=data[target])

# %% [markdown]
# 2) 수치화 : 상관분석

# %%
spst.pearsonr(data[feature],data[target])
# Out:
# (0.06407872955062152, 0.2009398289418295)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# + 경쟁사 가격 -> 판매량 관련 없다.
# + 왜???

# %% [markdown]
# + 가격경쟁력 변수 추가

# %%
data['Price_diff']=data['CompPrice']-data['Price']

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,3,1)
sns.scatterplot(x=data['Price'],y=data[target])

plt.subplot(1,3,2)
sns.scatterplot(x=data['CompPrice'],y=data[target])

plt.subplot(1,3,3)
sns.scatterplot(x=data['Price_diff'],y=data[target])
# Out:
# <AxesSubplot:xlabel='Price_diff', ylabel='Sales'>

# %%
spst.pearsonr(data['Price'],data[target]) #음의 상관관계
# Out:
# (-0.4449507278465726, 7.61818701191294e-21)

# %%
spst.pearsonr(data['CompPrice'],data[target]) #관계없음
# Out:
# (0.06407872955062152, 0.2009398289418295)

# %%
spst.pearsonr(data['Price_diff'],data[target]) #강한 상관관계
# Out:
# (0.5979217124533921, 3.877120641788835e-40)

# %% [markdown]
# ### (2) 범주형 X --> Y
#
# * 모든 범자형 X에 대해서 Y와 비교하여 차트를 그리고 수치화 하시오.
#
# ① 시각화 : 평균비교 barplot
# ② 수치화 : t-test, anova

# %% [markdown]
# #### ① ShelveLoc-> Sales

# %%
feature='ShelveLoc'

# %% [markdown]
# 1) 시각화 : 평균비교 barplot

# %%
# sns.barplot는 두 범주의 평균 비교 sns.barplot
sns.barplot(x=target, y=feature, data=data)
plt.grid()
plt.show()

# %% [markdown]
# 2) 수치화 : t-test, anova

# %%
data.isna().sum()
# Out:
# Sales          0
# CompPrice      0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# US             0
# dtype: int64

# %%
# 범주 3개 anova
data_g=data.loc[data[feature]=='Good',target]
data_m=data.loc[data[feature]=="Medium",target]
data_b=data.loc[data[feature]=="Bad",target]

# %%
spst.f_oneway(data_g,data_b,data_m)
# Out:
# F_onewayResult(statistic=92.22990509910346, pvalue=1.26693609015938e-33)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# + 관계없다.

# %% [markdown]
# #### ② US-> Sales

# %%
feature='US'

# %% [markdown]
# 1) 시각화 : 평균비교 barplot

# %%
data[target].isna().sum()
# Out:
# 0

# %%
# sns.barplot는 두 범주의 평균 비교 sns.barplot
sns.barplot(x=target, y=feature, data=data)
plt.grid()
plt.show()

# %%
data[feature].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# 2) 수치화 : t-test, anova

# %%
# 범주 3개 anova
data_Y=data.loc[data[feature]=='Yes',target]
data_N=data.loc[data[feature]=="No",target]

# %%
spst.ttest_ind(data_Y,data_N)
# Out:
# Ttest_indResult(statistic=3.589738747802499, pvalue=0.00037233958701471517)

# %% [markdown]
# 3) 시각화와 수치화 결과로부터 파악한 내용을 적어 봅시다.

# %% [markdown]
# + 관련이 있다.

# %% [markdown]
# ### (3) 관계 정리하기

# %% [markdown]
# ① 강한관계

# %% [markdown]
# ShelveLox,Price_diff

# %% [markdown]
# ② 중간관계

# %% [markdown]
# US,Price, Age,Advertising,

# %% [markdown]
# ③ 관계없음

# %% [markdown]
# CompPrice, popluation

# %% [markdown]
# # 2.범주형 Y

# %% [markdown]
# ## 1.1 타이타닉 탑승객 데이터 : 기본

# %% [markdown]
# ![](https://images0.persgroep.net/rcs/0XaEsm6zKVcBbpINLInGGmU2F8w/diocontent/22495473/_crop/2/111/1997/1128/_fitwidth/763?appId=93a17a8fd81db0de025c8abd1cca1279&quality=0.8)

# %% [markdown]
# |	변수	|	설명	|	값 설명	|
# |	----	|	----	|	----	|
# |	survived	|	생존여부	|	0 - 사망, 1- 생존	|
# |	Pclass	|	Ticket class	|	1 = 1st, 2 = 2nd, 3 = 3rd	|
# |	Sex	|	성별	|		|
# |	Age	|	Age in years	|		|
# |	Sibsp	|	# of siblings / spouses aboard the Titanic	|		|
# |	Parch	|	# of parents / children aboard the Titanic	|		|
# |	Ticket	|	Ticket number	|		|
# |	Fare	|	Passenger fare	|		|
# |	Cabin	|	Cabin number	|		|
# |	Embarked	|	Port of Embarkation	|	C = Cherbourg, Q = Queenstown, S = Southampton	|

# %%
titanic = pd.read_csv('https://bit.ly/3FsgwkJ')
titanic.head()

# %%
target = 'Survived'

# %% [markdown]
# ### (1) 숫자형 X --> 범주형 Y
#
# * 그래프 : histogram, densityplot
# * 수치화 : 로지스틱회귀
# * 관계 평가

# %% [markdown]
# #### ① Age --> Survived

# %% [markdown]
# 1) 그래프 : histogram, densityplot

# %% [markdown]
# 2) 수치화 : 로지스틱회귀

# %% [markdown]
# 3) 관계 평가하기

# %% [markdown]
# 4) 추가 분석할 내용 정리

# %% [markdown]
# #### ② Fare --> Survived

# %% [markdown]
# 1) 그래프 : histogram, densityplot

# %% [markdown]
# 2) 수치화 : 로지스틱회귀

# %% [markdown]
# 3) 관계 평가하기

# %% [markdown]
# 4) 추가 분석할 내용 정리

# %% [markdown]
# ### (2) 범주형 X --> 범주형 Y
#
# * 교차표(pd.crosstab())
# * 시각화( Stacked Bar, Mosaic)
# * 가설검정(카이제곱검정)
# * 관계 평가

# %% [markdown]
# #### ① Sex --> Survived

# %% [markdown]
# 1) 교차표(pd.crosstab())

# %% [markdown]
# 2) 시각화( Stacked Bar, Mosaic)

# %% [markdown]
# 3) 가설검정(카이제곱검정)

# %% [markdown]
# 4) 관계 평가하기

# %% [markdown]
# 5) 추가 분석하기

# %% [markdown]
# #### ② Pclass --> Survived

# %% [markdown]
# 1) 교차표(pd.crosstab())

# %% [markdown]
# 2) 시각화( Stacked Bar, Mosaic)

# %% [markdown]
# 3) 가설검정(카이제곱검정)

# %% [markdown]
# 4) 관계 평가하기

# %% [markdown]
# 5) 추가 분석하기

# %% [markdown]
# #### ③ Embarked --> Survived

# %% [markdown]
# 1) 교차표(pd.crosstab())

# %% [markdown]
# 2) 시각화( Stacked Bar, Mosaic)

# %% [markdown]
# 3) 가설검정(카이제곱검정)

# %% [markdown]
# 4) 관계 평가하기

# %% [markdown]
# 5) 추가 분석하기

# %% [markdown]
# ### (3) 관계 정리하기

# %% [markdown]
# ① 강한관계

# %% [markdown]
# ② 중간관계

# %% [markdown]
# ③ 관계없음
