# %% [markdown]
# ## AIVLE school 추석 이벤트

# %% [markdown]
# ### 주제 : 추석전일(22.9.9) 12시 정오 고속도로 서울 TG출발 -> 부산 TG 도착 소요 시간 예측

# %% [markdown]
# ### 고속도로 공공 데이터 http://data.ex.co.kr/

# %% [markdown]
# #### 고속도로 유형
# ![image.png](attachment:0ff0468a-6ac7-4fc0-a302-a78f64b0f6a6.png)

# %% [markdown]
# ![image.png](attachment:b04a5634-0b85-4e54-9a5d-8cfa397d91f7.png)

# %% [markdown]
# ### 선택경로
# <strong>경부(서울 ~ 신갈) + 영동 (신갈 ~ 여주) + 중부내륙 (여주 ~ 김천) + 경부 (김천 ~ 대구) + 중앙 (대구 ~ 부산)</strong>

# %% [markdown]
# 경로 선택 이유 : 경부 고속도로의 경우 충청남도, 전라남도, 전라북도로 연결된 도시가 많다. 대도시들이 많기 떄문에 교통량도 많을 것으로 예상한다.
# 따라서 최소시간을 위해서 다음과 같은 경로를 선택하였다.

# %% [markdown]
# #### 21년도 추석 전일 데이터 수집

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('check.csv')

# %%
data.head()
# Out:
#          날짜  시간  소요시간   이용차량   기온(°C)  강수량(mm)  풍속(m/s)  지면온도(°C)
# 0  20210821   0  4:47  39,662    24.8      0.0      1.3      24.5
# 1  20210821   1  4:48  26,076    24.5      0.0      2.0      24.0
# 2  20210821   2  4:31  19,980    24.0      0.0      2.1      23.3
# 3  20210821   3     0  18,449    24.1      0.0      2.5      23.6
# 4  20210821   4     0  26,091    24.1      0.0      2.3      23.7
