# %% [markdown]
# ### 네이버 중고나라 게시글 데이터 수집
# - selenium에서 iframe에 있는 데이터 수집

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
url="https://cafe.naver.com/joonggonara.cafe"

# %%
# 1. 웹브라우저 열기 및 페이지 이동
driver=webdriver.Chrome()
driver.get(url)

# %%
import time

# %%
print(1)
time.sleep(3)
print(2)
# Out:
# 1
# 2

# %%
# 2. 검색창에 에어팟 맥스 입력하고 검색 머튼 클릭
keyword="에어팟 맥스"
driver.find_element(By.CSS_SELECTOR,"#topLayerQueryInput").send_keys(keyword)

# %%
driver.execute_script("searchBoard();")

# %%
# 3. 게시글 목록 데이터 수집 : iframe
selector=".article-board>table>tbody>tr"
elements=driver.find_elements(By.CSS_SELECTOR,selector)
len(elements)
# Out:
# 0

# %%
# iframe 이동!!

# %%
#iframe으로 driver 이동
iframe=driver.find_element(By.CSS_SELECTOR,"#cafe_main")
iframe
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="8d913902f8f965e151888d0a3918c07e", element="8c1f38e6-f9ce-4a77-9514-20b3cac2bc35")>

# %%
driver.switch_to.frame(iframe)

# %%
selector=".article-board>table>tbody>tr"
elements=driver.find_elements(By.CSS_SELECTOR,selector)
len(elements)
# Out:
# 15

# %%
element=elements[0]

# %%
title=element.find_element(By.CSS_SELECTOR,".article").text
writer=element.find_element(By.CSS_SELECTOR,".p-nick").text
title,writer
# Out:
# ('민트급 에어팟 맥스 스페이스그레이', '덕9아빠')

# %%
data=[]
for element in elements:
    data.append({
        "title":element.find_element(By.CSS_SELECTOR,".article").text,
        "writer":element.find_element(By.CSS_SELECTOR,".p-nick").text,
    })
df=pd.DataFrame(data)
df.tail(2)
# Out:
#                                         title   writer
# 13  스타벅스x케이스티파이 콜라보 한정 아이폰 13프로맥스 에어팟 케이스 팝니다  천천히하나하나
# 14                   에어팟 맥스 실버 새제품 팝니다미개봉 새제품    긴하루내일

# %%
#원래 default frame 으로 이동
driver.switch_to.default_content()

# %%
# 4. 웹브라우저 종료
driver.quit()
