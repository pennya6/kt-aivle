# %% [markdown]
# # 1일차 Review : 같은 문제 다시 풀어보기
#
#     학습은 10번으로!

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

# %%
x = cancer.data
y = cancer.target

# %%
x.shape, y.shape
# Out:
# ((569, 30), (569,))

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2022,test_size=0.2)

# %%
#####################
# 라이브러리 불러오기
#####################
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
########
# 모델링
########
keras.backend.clear_session()
il=keras.layers.Input(shape=(30,),name='inputLayer')
ol=keras.layers.Dense(1,activation='sigmoid')(il)
model=keras.models.Model(inputs=il,outputs=ol)
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputLayer (InputLayer)     [(None, 30)]              0
#
#  dense (Dense)               (None, 1)                 31
#
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########
# 모델 학습
###########
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 1s 3ms/step - loss: 157.1042 - accuracy: 0.3648
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 144.9534 - accuracy: 0.3648
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 132.9272 - accuracy: 0.3648
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 120.7781 - accuracy: 0.3648
# Epoch 5/10
# 15/15 [==============================] - 0s 2ms/step - loss: 108.7259 - accuracy: 0.3648
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 96.4668 - accuracy: 0.3648
# Epoch 7/10
# 15/15 [==============================] - 0s 3ms/step - loss: 84.4885 - accuracy: 0.3648
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 72.5711 - accuracy: 0.3648
# Epoch 9/10
# 15/15 [==============================] - 0s 2ms/step - loss: 60.5424 - accuracy: 0.3648
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 48.5085 - accuracy: 0.3648

# %%
###########
# 모델 예측
###########
y_pred=model.predict(x_test)

# %% [markdown]
# # 히든 레이어 추가하여 모델링!
#
#     히든 레이어 2개를 추가하여 다시 모델링!
#     히든 레이어 노드 수 : 32
#     히든 레이어 activation = 'relu'

# %%
########
# 모델링
########
keras.backend.clear_session()
il=keras.layers.Input(shape=(30,))
hidden=keras.layers.Dense(32,activation='relu')(il)
hidden2=keras.layers.Dense(32,activation='relu')(hidden)
ol=keras.layers.Dense(1,activation='sigmoid')(hidden2)
model=keras.models.Model(inputs=il,outputs=ol)
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 30)]              0
#
#  dense (Dense)               (None, 32)                992
#
#  dense_1 (Dense)             (None, 32)                1056
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,081
# Trainable params: 2,081
# Non-trainable params: 0
# _________________________________________________________________

# %%
###########
# 모델 학습
###########
model.fit(x_train,y_train,epochs=10)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 0s 2ms/step - loss: 4.8644 - accuracy: 0.5648
# Epoch 2/10
# 15/15 [==============================] - 0s 2ms/step - loss: 1.8538 - accuracy: 0.5780
# Epoch 3/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.6026 - accuracy: 0.8308
# Epoch 4/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.3083 - accuracy: 0.8857
# Epoch 5/10
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2550 - accuracy: 0.9099
# Epoch 6/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.9187
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2539 - accuracy: 0.9099
# Epoch 8/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2483 - accuracy: 0.9143
# Epoch 9/10
# 15/15 [==============================] - 0s 3ms/step - loss: 0.2574 - accuracy: 0.9011
# Epoch 10/10
# 15/15 [==============================] - 0s 2ms/step - loss: 0.2515 - accuracy: 0.9099

# %%
###########
# 모델 예측
###########
y_pred=model.predict(x_test)
