# %% [markdown]
# # 클러스터링 (Clustering) 실습

# %%
#구글드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# 입력 데이터 위치
Path = '/content/drive/MyDrive/Colab Notebooks/aivle/언어지능딥러닝/Data/clustering/' 

# 각 주제별 100건의 뉴스 데이터
# Read an Excel file into a pandas DataFrame
# DataFrame : 2차원 데이터구조. Row, Column, Series(각 Column에 있는 데이터들)로 구성
climate = pd.read_excel(Path+'news_climate change.xlsx')
mobility = pd.read_excel(Path+'news_mobility.xlsx')
probiotics = pd.read_excel(Path+'news_probiotics.xlsx')

# 주제 column을 추가
climate['주제'] = '기후위기'
mobility['주제'] = '모빌리티'
probiotics['주제'] = '유산균'

# 각 주제별 70건의 뉴스데이터를 가져와서 입력용 데이터를 생성
# pandas.concat(objs, axis=0, ignore_index=Faslse, ...)
# axis=0, 0: 위+아래로 합치기, 1: 왼쪽+오른쪽으로 합치기
# ignore_index=True : 기존 index를 무시. The resulting axis will be labeled 0, …, n - 1. 
data = pd.concat([climate[:70], mobility[:70], probiotics[:70]], ignore_index=True)

# 뉴스기사 body, title을 기준으로 중복을 제거
# DataFrame.drop_duplicates : Returns DataFrame with duplicate rows removed.
data_unique = data.drop_duplicates(['body']).drop_duplicates(['title']) # 중복 제거

# 중복 제거된 데이터 건수를 확인
# DataFrame.shape : Returns a tuple representing the dimensionality of the DataFrame.
data.shape, data_unique.shape
# Out:
# ((210, 5), (198, 5))

# %% [markdown]
# 중복으로 들어있는 기사를 제거하고 기사들의 순서를 무작위로 섞습니다.

# %%
# 데이터 순서를 셔플링
# frac: 랜덤 추출할 비율 (1 == 전체 데이터를 셔플링)
# random_state: 랜덤 추출할 값에 seed 설정하면, 항상 같은 결과를 생성
# reset_index: Reset the index. Use drop parameter to avoid the old index being added as a column
data_shuffled = data_unique.sample(frac=1, random_state=16).reset_index(drop=True) 
data_shuffled.head(3)
# Out:
#                   date                                  title  \
# 0  2022-08-26 14:36:00  '자율주행차에서 브레이크 고장나면?'…현대차그룹, 대응 시스템 공개
# 1  2022-08-16 19:50:00    미-러 핵전쟁 시 50억명 이상 굶어 죽는다"" 美 연구팀 발표
# 2  2022-08-29 20:07:00         [여기는 전남] 전남도, 적조 피해 예방 총력 대응 외
#
#                                                 body channel    주제
# 0  [자료=현대자동차] 현대차그룹이 오늘(26일) 특허 출원한 자율주행 차량의 브레이크...    news  모빌리티
# 1  미국과 러시아가 핵전쟁을 할 경우 전 세계 50억명 이상의 사람이 굶주림으로 숨질 ...    news  기후위기
# 2  [KBS 광주]고흥 외나로도에서 여수 돌산 해역까지 적조 주의보가 내려진 가운데 전...    news  기후위기

# %%
# DataFrame.iloc : integer-location based indexing for selection by position
data_shuffled.iloc[0]['title']
data_shuffled.iloc[0]['body']
# Out:
# '[자료=현대자동차] 현대차그룹이 오늘(26일) 특허 출원한 자율주행 차량의 브레이크 고장 대응 시스템 을 HMG 테크 사이트 에 공개했습니다. 현대차그룹은 해당 기술이 완전 자율주행 모빌리티를 전제로 하며, 브레이크 장치에 오류가 발생하는 예기치 못한 상황에서 다른 차량 간의 상호작용으로 피해를 최소화하는 사고 대응 기술이라고 설명했습니다. 브레이크 고장 시스템으로, 자율주행 차량이 주행 도중 제동이 필요한 상황에서 전자 제어장치를 통해 메인 제동 장치의 작동을 확인하고, 반응이 없으면 전자 제어장치는 다시 한번 보조 제동 장치를 거쳐 제동 가능 여부를 판별합니다. 이때 보조 제동 장치까지 사용이 불가능하다고 판단되면 전자 제어장치는 가장 가까운 자율주행 관제시스템을 향해 제동 시스템에 문제가 있다는 신호를 전달합니다. 정보를 전달받은 관제시스템은 고장 차량과 가장 가까이에서 주행 중인 차량에게 구조 신호를 보냅니다. 신호를 수신한 자율주행 차량은 고장 차량을 안전하게 정지시키기 위해 고장 차량이 관제시스템에게 전달한 정보를 토대로 조향 시스템을 제어합니다. 또한, 구조 진행 상황을 관제시스템에게 전달함과 동시에 고장 차량과 같은 차선으로 주행하도록 접근합니다. 관제시스템은 고장 차량의 무사 처리를 위해 주변 차량들이 해당 차선에 주행하지 않도록 지시합니다. 같은 차선으로 이동한 차량은 주행 속도와 조향 시스템을 꾸준히 조절하며 고장 차량의 범퍼에 접촉해 차량의 속도를 서서히 줄입니다. 꾸준한 차량 제어로 고장 차량이 완전히 멈추면 관제시스템에 구조 완료 신호를 보낸 후 구조 작업을 끝냅니다. 무선 통신을 거쳐 주변 차량과의 상호작용으로 사고를 완화하는 것입니다. 현대차그룹은 "브레이크 고장 대응 시스템 기술에 대한 특허를 미국, 중국, 한국에 출원했으며, 가능성이 희박한 만약의 상황까지 고려한 전방위 안전 체계를 구축하기 위해 자율주행 기술의 기초부터 완성도를 꾸준히 높여가고 있다"고 말했습니다.'

# %% [markdown]
# 먼저 형태소 분석을 하기 위해 konlpy를 설치합니다.

# %%
# 한국어 형태소 분석기를 포함하고 있는 파이썬 패키지 설치
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 54.1 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0

# %% [markdown]
# ##**< 뉴스 기사 단어 빈도 분석 >**

# %% [markdown]
# 오픈소스 한국어 형태소분석기 중 하나인 Hannanum 패키지를 import하고 클래스 객체를 생성합니다.
#
# 빈 리스트를 하나 만들고 `hannanum` 클래스를 이용해 명사만을 추출하여 저장합니다.

# %%
# 데이터에서 첫번째 기사 내용을 가져와서 명사만 추출합니다
from konlpy.tag import Hannanum
hannanum = Hannanum() # 객체 생성

temp = hannanum.nouns(data_shuffled.loc[0]['body']) # sentence 삽입시 형태소 분석 실시
print(temp)
# Out:
# ['[자료=현대자동차]', '현대차그룹', '오늘(26일)', '특허', '출원', '자율주행', '차량', '브레이크', '고장', '대응', '시스템', '을', '테크', '사이트', '공개', '현대차그룹', '해당', '기술', '완전', '자율주행', '모빌리티', '전제', '브레이크', '장치', '오류', '발생', '예기치', '상황', '차량', '간', '상호작용', '피해', '최소', '대응', '기술', '설명', '브레이크', '고장', '시스템', '자율주행', '차량', '주행', '도중', '제동', '필요', '상황', '전자', '제어장치', '제동', '장치', '작동', '확인', '반응', '전자', '제어장치', '한번', '보조', '제동', '장치', '제동', '가능', '여부', '판별', '이때', '보조', '제동', '장치', '사용', '불가능', '판단', '전자', '제어장치', '자율주행', '관제시스템', '제동', '시스템', '문제', '신호', '전달', '정보', '전달', '관제시스템', '고장', '차량', '가까이', '주행', '중', '차량', '구조', '신호', '신호', '수', '한', '자율주행', '차량', '고장', '차량', '안전', '정지', '고장', '차량', '관제시스템', '전달한', '정보', '토대', '조향', '시스템', '제', '구조', '진행', '상황', '관제시스템', '전달함', '고장', '차량', '차선', '주행', '접근', '관제시스템', '고장', '차량', '무사', '처리', '주변', '차량들', '해당', '차선', '주행', '지시', '차선', '이동한', '차량', '주행', '속도', '조향', '시스템', '조절', '고장', '차량', '범퍼', '접촉', '차량', '속도', '줄', '한', '차량', '제어', '고장', '차량', '관제시스템', '구조', '완료', '신호', '후', '구조', '작업', '무선', '통신', '주변', '차량', '상호작용', '사고', '완화', '것', '현대차그룹', '브레이크', '고장', '대응', '시스템', '기술', '특허', '미국,', '중국,', '한국', '출원', '가능성', '희박', '만약', '상황', '전방위', '전', '체계', '구축', '자율주행', '기술', '기초', '완성도', '말']

# %% [markdown]
# 주제와 연관된 단어들이 자주 출현한 것을 볼 수 있습니다.

# %%
# 명사만 추출된 리스트
word_list=temp

# 문서에 출현한 각 명사로부터 Series 객체를 생성 (index는 0부터 시작하는 정수값)
# 0 차량
# 1 고장
# 2 제동
# 3 차량
# 4 고장
# 5 ...
word_list=pd.Series([x for x in word_list if len(x)>1])

# pd.Series.value_counts: Returns a Series containing counts of unique values.
# The resulting object will be in descending order so that the first element is the most frequently-occurring element.  
word_list.value_counts().head(10), data_shuffled.iloc[0]['주제']
# Out:
# (차량       16
#  고장       10
#  관제시스템     6
#  자율주행      6
#  제동        6
#  시스템       6
#  주행        5
#  신호        4
#  장치        4
#  기술        4
#  dtype: int64, '모빌리티')

# %% [markdown]
# ***
#
# ##**< DBSCAN 예제 : 기사 분석하기 >**
# 기후변화, 유산균, 모빌리티에 관한 기사 제목과 기사 내용을 저장한 데이터에 대해 DBSCAN을 적용합니다.

# %%
# 기사 내용중 명사만을 추출하여 docs 리스트에 저장합니다.
docs = []
for i in data_shuffled['body']:
    docs.append(hannanum.nouns(i))

# 공백 문자를 넣어서 각 단어를 합칩니다.
for i in range(len(docs)):
    docs[i] = ' '.join(docs[i])

docs[0]
# Out:
# '[자료=현대자동차] 현대차그룹 오늘(26일) 특허 출원 자율주행 차량 브레이크 고장 대응 시스템 을 테크 사이트 공개 현대차그룹 해당 기술 완전 자율주행 모빌리티 전제 브레이크 장치 오류 발생 예기치 상황 차량 간 상호작용 피해 최소 대응 기술 설명 브레이크 고장 시스템 자율주행 차량 주행 도중 제동 필요 상황 전자 제어장치 제동 장치 작동 확인 반응 전자 제어장치 한번 보조 제동 장치 제동 가능 여부 판별 이때 보조 제동 장치 사용 불가능 판단 전자 제어장치 자율주행 관제시스템 제동 시스템 문제 신호 전달 정보 전달 관제시스템 고장 차량 가까이 주행 중 차량 구조 신호 신호 수 한 자율주행 차량 고장 차량 안전 정지 고장 차량 관제시스템 전달한 정보 토대 조향 시스템 제 구조 진행 상황 관제시스템 전달함 고장 차량 차선 주행 접근 관제시스템 고장 차량 무사 처리 주변 차량들 해당 차선 주행 지시 차선 이동한 차량 주행 속도 조향 시스템 조절 고장 차량 범퍼 접촉 차량 속도 줄 한 차량 제어 고장 차량 관제시스템 구조 완료 신호 후 구조 작업 무선 통신 주변 차량 상호작용 사고 완화 것 현대차그룹 브레이크 고장 대응 시스템 기술 특허 미국, 중국, 한국 출원 가능성 희박 만약 상황 전방위 전 체계 구축 자율주행 기술 기초 완성도 말'

# %% [markdown]
# 처음 한나눔 분석기를 이용해서 명사만 추출한 docs의 구조는 다음과 같은 이중 리스트로 구성되어 있습니다.
#
# - [[문장1], [문장2], ... , [문장70]]
#
# 두번째 for문을 이용하면 docs는 다음과 같이 변형되고
#
# - [문장1, 문장2, ... , 문장70]
#
# 각 리스트의 원소가 명사들 사이에 공백이 삽입된 텍스트로 바뀝니다.

# %%
# sklearn.feature_extraction.text.TfidfVectorizer :
# Converts a collection of raw documents to a matrix of TF-IDF features (document-term matrix)
# ngram_range(min_n, max_n): all values of n such that min_n <= n <= max_n will be used. 
# min_df : ignore terms that have a document frequency lower than the given threshold.

#tfitvector -> 벡터화 
# countvector 와 유사
# tf-idf 가중치 부여
from sklearn.feature_extraction.text import TfidfVectorizer

# n(1 to 5)gram 을 사용하여 위 기사의 명사들을 tfidf vector로 변환
# ngram 부여
# 최소 term 3개 이상 문서에 등장하는 것만!
tfidf_vectorizer = TfidfVectorizer(min_df = 3, ngram_range=(1,5))
tfidf_vectorizer.fit(docs)
vector = tfidf_vectorizer.transform(docs).toarray()
print(vector.shape) # num_of_documents X vocab
# Out:
# (198, 3324)

# %% [markdown]
# sklearn.cluster.DBSCAN:
# eps : maximum distance between two samples (default 0.5)
# min_samples=5 : The number of samples (or total weight) in a neighborhood for a point to be considered as a core point (default 5)
# metric: The metric to use when calculating distance between instances in a feature array. (default 'euclidean')

# %%
# sklearn.cluster.DBSCAN: Performs DBSCAN clustering from vector array
# eps: maximum distance between two samples (default 0.5)
# min_samples: The number of samples in a neighborhood for a point to be considered as a core point (default 5) 
# metric: The metric to use when calculating distance between instances in a feature array. (default 'euclidean')
# 'cosine' distance == (1 - cosine similarity)
# ex) If 2 vectors are perfectly the same then the similarity is 1 (angle=0 hence 𝑐𝑜𝑠(𝜃)=1), and the distance is 0 (1–1=0).
from sklearn.cluster import DBSCAN
import numpy as np

vector = np.array(vector)
model = DBSCAN(eps=0.5, min_samples=3, metric = "cosine") 
result = model.fit_predict(vector) # Computes clusters from a data and predict labels.

# %%
# 클러스터 번호 -1에는 노이즈 데이터로 판별되어 클러스터링이 안된 문서들이 들어 있음
print('클러스터 번호: 클러스터에 속한 기사의 수')
result_dict = {str(i):list(result).count(i) for i in set(result)} # result의 각 클러스터에 속한 기사수를 카운트
result_dict
# Out:
# 클러스터 번호: 클러스터에 속한 기사의 수
# {'0': 6,
#  '1': 6,
#  '2': 3,
#  '3': 5,
#  '4': 3,
#  '5': 4,
#  '6': 3,
#  '7': 3,
#  '8': 3,
#  '9': 3,
#  '-1': 159}

# %% [markdown]
# DBSCAN 을 통해 클러스터링된 index 결과를 데이터 프레임에 추가합니다.
#
# 클러스터 -1에는 노이즈 데이터로 판별이 나서 클러스터링이 안된 문서가 들어 있습니다.

# %%
# 클러스터 번호를 column으로 추가
data_shuffled['result'] = result

# %%
sentences = []
max_cluster_num = 0
for cluster_num in set(result):
    sentence = ''

    # -1은 노이즈 판별이 났거나 클러스터링이 안된 경우
    if(cluster_num == -1): 
        continue
    else:
        max_cluster_num = cluster_num         # 생성된 클러스터의 갯수를 카운트
        temp_df = data_shuffled[data_shuffled['result'] == cluster_num] # cluster num 별로 조회

        print("cluster num : {}".format(cluster_num))
        # zip: 동일한 개수로 이루어진 자료형을 묶어 준다
        for data in zip(temp_df['title'], temp_df['body'], temp_df.iloc): 
            title, body, my_data = data
            print(my_data['주제'], ':', title) # 주제, 기사 제목을 출력
            sentence += body + ' '
        print()
    sentences.append(sentence)
# Out:
# cluster num : 0
# 유산균 : 야쿠르트도 10% 오른다‥hy, 내달 일부 제품 가격 인상
# 유산균 : 야쿠르트 라이트, 가격 10% 인상…쿠퍼스 2700원 된다
# 유산균 : hy, 야쿠르트 라이트 등 일부 제품 '가격 인상'
# 유산균 : "야쿠르트도 오른다"…hy, 내달 일부 제품 가격 인상
# 유산균 : 야쿠르트도 10% 오른다...hy, 9월부터 일부 제품 인상
# 유산균 : hy, 9월부터 일부 제품 가격 오른다…"제조원가 부담 심화"
#
# cluster num : 1
# 모빌리티 : 대리운전노조·카카오노조, “카카오모빌리티 매각 철회 환영”
# 모빌리티 : 대리운전노조, 카카오모빌리티 본사 앞 천막농성 돌입
# 모빌리티 : 카카오 “카카오모빌리티 지분 매각 추진 중단”
# 모빌리티 : "카카오모빌리티 매각 철회해야"…대리운전노조, 천막농성 돌입
# 모빌리티 : 카카오, 카카오모빌리티 지분 안 판다…진짜 속내는?
# 모빌리티 : 카카오 ""카카오모빌리티 지분 매각 추진 중단""
#
# cluster num : 2
# 유산균 : CJ웰케어, ‘BYO 유산균’ 누적 매출 2,500억원 돌파
# 유산균 : CJ웰케어, 바이오유산균 출시후 누적 매출 2500억 돌파
# 유산균 : CJ웰케어, 'BYO 유산균' 누적 매출 2500억원 돌파
#
# cluster num : 3
# 모빌리티 : 공정위, KG모빌리티 쌍용차 주식 취득 승인…“경쟁제한 미미”
# 모빌리티 : 공정위, KG의 쌍용차 인수 승인…"경쟁 제한 우려 미미"
# 모빌리티 : 공정위, 'KG-쌍용차' 기업결합 승인…"경쟁제한 우려 없다"
# 모빌리티 : 공정위, KG 쌍용차 인수 허가…채권단 동의가 관건
# 모빌리티 : 공정위, KG그룹의 쌍용차 인수 승인…"경쟁제한 우려 없다"
#
# cluster num : 4
# 기후위기 : 주미대사 “한미, 美인플레법 협의 합의”…法 개정까지 염두 총력
# 기후위기 : 바이든 인플레 감축법 서명…한국 전기차 보조금 제외
# 기후위기 : 한국 전기차, 미국 보조금 혜택 대상서 제외
#
# cluster num : 5
# 유산균 : 추석 선물도 라방으로… CJ올리브영, '올영라이브' 진행
# 유산균 : CJ올리브영, 추석 특집 '올영라이브' 진행
# 유산균 : CJ올리브영, 추석 특집 라이브커머스 '올영라이브' 진행
# 유산균 : 추석 선물도 라방으로…CJ올리브영, 추석 특집 '올영라이브' 진행
#
# cluster num : 6
# 유산균 : 홈앤쇼핑, PB브랜드 '이데이잇츠 콤부차' 출시
# 유산균 : 매일유업 콤부차, 구매 만족도 98% 달성…"깔끔한 발효 풍미"
# 유산균 : [중기소식]홈앤쇼핑, 자체 브랜드 '이데이잇츠' 출시 등
#
# cluster num : 7
# 유산균 : 일동바이오사이언스 ""프로바이오틱스 원료6종 캐나다 등록""
# 유산균 : 일동바이오사이언스, 프로바이오틱스 6종 캐나다 NHP 등록
# 유산균 : 일동바이오, 프로바이오틱스 6종 캐나다 NHP 등록…"미주 시장 개척에 속도"
#
# cluster num : 8
# 유산균 : 케어비, '이유식 도락기행' 프로모션 진행
# 유산균 : 남양유업, '우리아이 영양 맞춤 이유식' 강의 진행
# 유산균 : 남양유업 배달 이유식 '케어비', '이유식도락 기행' 프로모션 진행
#
# cluster num : 9
# 모빌리티 : 대리운전업 갈등 2라운드…""대기업 꼼수로 시장 진출""
# 모빌리티 : 대리운전연합, 최태원 SK 회장에 손편지…"티맵 갈등 중재해달라"
# 모빌리티 : 대리운전연합, 내일부터 티맵 규탄대회…"사업확장제한 권고 어겨"

# %%
#클러스터 1번에 속한 데이터 확인
data_cluster1 = data_shuffled[data_shuffled.result==1]
data_cluster1
len(data_cluster1)
# Out:
# 6

# %%
# num_to_display: 각 클러스터당 출력할 최대 문서 개수
num_to_display = 5
# max_cluster_num: 생성된 클러스터 갯수
print(max_cluster_num)
# Out:
# 9

# %%
# 각 클러스터 마다 데이터 출력해주기
for i in range(max_cluster_num+1):
  data_cluster = data_shuffled[data_shuffled.result==i]
  data_num = len(data_cluster)

  if len(data_cluster) > num_to_display:
    data_cluster = data_cluster[0:num_to_display]

  print('----- 클러스터 %i -----' %i)
  print('총 데이터 개수: %i' % data_num)
  print(data_cluster)
  print()
# Out:
# ----- 클러스터 0 -----
# 총 데이터 개수: 6
#                     date                              title  \
# 6    2022-08-18 11:23:00   야쿠르트도 10% 오른다‥hy, 내달 일부 제품 가격 인상
# 89   2022-08-18 10:45:00   야쿠르트 라이트, 가격 10% 인상…쿠퍼스 2700원 된다
# 90   2022-08-18 11:09:00       hy, 야쿠르트 라이트 등 일부 제품 '가격 인상'
# 91   2022-08-18 10:32:00     "야쿠르트도 오른다"…hy, 내달 일부 제품 가격 인상
# 120  2022-08-18 15:10:00  야쿠르트도 10% 오른다...hy, 9월부터 일부 제품 인상
#
#                                                   body channel   주제  result
# 6    hy 제공 옛 한국야쿠르트인 hy는 일부 제품에 대해 9월 1일 가격을 인상한다고 ...    news  유산균       0
# 89   hy(옛 한국야쿠르트)는 일부 제품에 대해 다음달 1일부터 가격을 인상한다고 오늘(...    news  유산균       0
# 90   [서울=뉴시스]김혜경 기자 = hy가 일부 제품에 대해 9월1일부터 가격을 인상한다...    news  유산균       0
# 91   ⓒhy [데일리안 = 임유정 기자] hy가 일부 제품에 대해 9월 1일부로 가격을 ...    news  유산균       0
# 120  [사진제공: hy] hy(옛 한국야쿠르트)가 일부 제품에 대해 9월 1일부로 가격을...    news  유산균       0
#
# ----- 클러스터 1 -----
# 총 데이터 개수: 6
#                     date                              title  \
# 7    2022-08-18 15:08:00   대리운전노조·카카오노조, “카카오모빌리티 매각 철회 환영”
# 104  2022-08-17 17:27:00       대리운전노조, 카카오모빌리티 본사 앞 천막농성 돌입
# 134  2022-08-18 10:17:00          카카오 “카카오모빌리티 지분 매각 추진 중단”
# 149  2022-08-17 17:58:00  "카카오모빌리티 매각 철회해야"…대리운전노조, 천막농성 돌입
# 182  2022-08-18 17:40:00       카카오, 카카오모빌리티 지분 안 판다…진짜 속내는?
#
#                                                   body channel    주제  result
# 7    전국대리운전노동조합과 카카오 노동조합은 카카오가 카카오모빌리티 지분 매각 추진을 중...    news  모빌리티       1
# 104  자료 제공: 연합뉴스 전국대리운전노동조합과, 카카오노동조합인 '크루 유니언'은 오늘...    news  모빌리티       1
# 134  카카오가 카카오모빌리티의 지분 일부 매각 추진을 중단한다고 오늘(18일) 공시했습니...    news  모빌리티       1
# 149  전국대리운전노동조합이 오늘(17일)부터 카카오·카카오모빌리티 본사 앞에 천막을 설치...    news  모빌리티       1
# 182  카카오가 자회사 카카오모빌리티의 지분을 팔지 않기로 했습니다. 카카오모빌리티 매각설...    news  모빌리티       1
#
# ----- 클러스터 2 -----
# 총 데이터 개수: 3
#                    date                              title  \
# 8   2022-08-31 07:38:00  CJ웰케어, ‘BYO 유산균’ 누적 매출 2,500억원 돌파
# 24  2022-08-31 08:12:00   CJ웰케어, 바이오유산균 출시후 누적 매출 2500억 돌파
# 69  2022-08-31 09:29:00   CJ웰케어, 'BYO 유산균' 누적 매출 2500억원 돌파
#
#                                                  body channel   주제  result
# 8   CJ웰케어는 ‘BYO 유산균(바이오)’이 출시 후 누적 매출 2,500억원을 돌파했...    news  유산균       2
# 24  [서울=뉴시스] 김동현 기자 = CJ웰케어는 '바이오 유산균'이 출시 후 누적 매출...    news  유산균       2
# 69  (CJ웰케어 제공) (서울=뉴스1) 이상학 기자 = CJ웰케어는 'BYO 유산균(바...    news  유산균       2
#
# ----- 클러스터 3 -----
# 총 데이터 개수: 5
#                     date                               title  \
# 13   2022-08-24 10:03:00  공정위, KG모빌리티 쌍용차 주식 취득 승인…“경쟁제한 미미”
# 23   2022-08-24 10:41:00    공정위, KG의 쌍용차 인수 승인…"경쟁 제한 우려 미미"
# 44   2022-08-24 13:28:00  공정위, 'KG-쌍용차' 기업결합 승인…"경쟁제한 우려 없다"
# 150  2022-08-24 11:50:00        공정위, KG 쌍용차 인수 허가…채권단 동의가 관건
# 164  2022-08-24 10:18:00   공정위, KG그룹의 쌍용차 인수 승인…"경쟁제한 우려 없다"
#
#                                                   body channel    주제  result
# 13   쌍용차 최종인수예정자로 선정된 KG그룹의 쌍용차 주식 취득을 공정거래위원회가 승인했...    news  모빌리티       3
# 23   공정거래위원회가 KG그룹이 쌍용자동차를 인수하는 기업결합을 승인했다고 밝혔습니다. ...    news  모빌리티       3
# 44   공정거래위원회가 KG모빌리티와 쌍용자동차의 기업결합 건을 승인했다. 공정위는 24일...    news  모빌리티       3
# 150  [앵커] 공정거래위원회가 오늘(24일) 오전 쌍용차 최종인수예정자로 선정된 KG그룹...    news  모빌리티       3
# 164  공정거래위원회가 KG그룹의 쌍용자동차 인수를 승인했습니다. 공정위는 오늘(24일) ...    news  모빌리티       3
#
# ----- 클러스터 4 -----
# 총 데이터 개수: 3
#                     date                                title  \
# 18   2022-08-30 05:40:00  주미대사 “한미, 美인플레법 협의 합의”…法 개정까지 염두 총력
# 103  2022-08-17 11:23:00         바이든 인플레 감축법 서명…한국 전기차 보조금 제외
# 189  2022-08-17 16:13:00             한국 전기차, 미국 보조금 혜택 대상서 제외
#
#                                                   body channel    주제  result
# 18   조태용 주미한국대사는 미국의 인플레이션 감축법 제정에 따른 한국산 전기차 보조금 지...    news  기후위기       4
# 103  〈사진=AP 연합뉴스〉 조 바이든 미국 대통령이 백악관에서 기후변화 대응과 의료보장...    news  기후위기       4
# 189  ▲(위)현대 아이오닉5, (아래)기아 EV6 미국 인플레이션 감축법에 따라 세금공제...    news  기후위기       4
#
# ----- 클러스터 5 -----
# 총 데이터 개수: 4
#                     date                                 title  \
# 37   2022-08-24 10:11:00       추석 선물도 라방으로… CJ올리브영, '올영라이브' 진행
# 115  2022-08-24 11:22:00              CJ올리브영, 추석 특집 '올영라이브' 진행
# 122  2022-08-24 09:45:00       CJ올리브영, 추석 특집 라이브커머스 '올영라이브' 진행
# 136  2022-08-24 13:20:00  추석 선물도 라방으로…CJ올리브영, 추석 특집 '올영라이브' 진행
#
#                                                   body channel   주제  result
# 37   고물가·비대면 선물 수요 반영 추석특집 '올영라이브' 대표 이미지(올리브영 제공)....    news  유산균       5
# 115  [서울=뉴시스]이지영 기자 = CJ올리브영은 추석 특집 라이브커머스 '올영라이브'를...    news  유산균       5
# 122  24일·31일 2회 편성...화장품·건기식 등 선물세트 판매 CJ올리브영(이하 올리...    news  유산균       5
# 136  24일, 31일 총 2회 걸쳐 추석 선물 제안하는 라이브커머스 '올영라이브' 진행 ...    news  유산균       5
#
# ----- 클러스터 6 -----
# 총 데이터 개수: 3
#                     date                                title  \
# 59   2022-08-17 09:09:00           홈앤쇼핑, PB브랜드 '이데이잇츠 콤부차' 출시
# 63   2022-08-26 09:59:00  매일유업 콤부차, 구매 만족도 98% 달성…"깔끔한 발효 풍미"
# 138  2022-08-17 09:06:00      [중기소식]홈앤쇼핑, 자체 브랜드 '이데이잇츠' 출시 등
#
#                                                   body channel   주제  result
# 59   '맛있는 콤부차 레몬' 선봬…건기식도 순차 출시 이데이잇츠(홈앤쇼핑 제공) (서울=...    news  유산균       6
# 63   '더그레잇티 콤부차 오리지널·베리리치', 카카오 선판매 '구아검가수분해물' 함유해 ...    news  유산균       6
# 138  [서울=뉴시스] 홈앤쇼핑 '이데이잇츠' 콤부차. (사진=홈앤쇼핑 제공) 2022.0...    news  유산균       6
#
# ----- 클러스터 7 -----
# 총 데이터 개수: 3
#                    date                                        title  \
# 80  2022-08-23 11:40:00            일동바이오사이언스 ""프로바이오틱스 원료6종 캐나다 등록""
# 85  2022-08-23 16:58:00             일동바이오사이언스, 프로바이오틱스 6종 캐나다 NHP 등록
# 86  2022-08-23 17:11:00  일동바이오, 프로바이오틱스 6종 캐나다 NHP 등록…"미주 시장 개척에 속도"
#
#                                                  body channel   주제  result
# 80  [일동바이오사이언스 본사(일동제약그룹 제공=연합뉴스)] 일동바이오사이언스는 캐나다 ...    news  유산균       7
# 85  (사진=일동바이오사이언스 제공) *재판매 및 DB 금지 [서울=뉴시스] 송연주 기자...    news  유산균       7
# 86  "프로바이오틱스 원료 품질 및 안전성 확보" 일동바이오사이언스 본사 전경.ⓒ일동제약...    news  유산균       7
#
# ----- 클러스터 8 -----
# 총 데이터 개수: 3
#                     date                                  title  \
# 102  2022-08-24 08:24:00                케어비, '이유식 도락기행' 프로모션 진행
# 125  2022-08-30 08:37:00           남양유업, '우리아이 영양 맞춤 이유식' 강의 진행
# 129  2022-08-24 08:41:00  남양유업 배달 이유식 '케어비', '이유식도락 기행' 프로모션 진행
#
#                                                   body channel   주제  result
# 102  [서울=뉴시스] 김동현 기자 = 남양유업의 이유식 브랜드 케어비는 '한여름에도 우리...    news  유산균       8
# 125  [서울=뉴시스] 김동현 기자 = 남양유업이 다음달 2일 유튜브 채널을 통해 '우리아...    news  유산균       8
# 129  (남양유업 제공) (서울=뉴스1) 이상학 기자 = 남양유업의 영양 맞춤 배달 이유식...    news  유산균       8
#
# ----- 클러스터 9 -----
# 총 데이터 개수: 3
#                     date                                 title  \
# 114  2022-08-23 07:51:00       대리운전업 갈등 2라운드…""대기업 꼼수로 시장 진출""
# 119  2022-08-31 11:39:00  대리운전연합, 최태원 SK 회장에 손편지…"티맵 갈등 중재해달라"
# 171  2022-08-22 06:54:00   대리운전연합, 내일부터 티맵 규탄대회…"사업확장제한 권고 어겨"
#
#                                                   body channel    주제  result
# 114  【 앵커멘트 】 대리운전업을 둘러싼 대기업과 중소기업 갈등이 2라운드에 접어들고 있...    news  모빌리티       9
# 119  대리운전업 분야에 대한 대기업의 사업확장이 제한됐음에도 SK스퀘어의 자회사인 티맵모...    news  모빌리티       9
# 171  티맵모빌리티 "근거없는 주장" 대리운전업계는 대리운전업 분야에 대한 대기업의 사업확...    news  모빌리티       9
